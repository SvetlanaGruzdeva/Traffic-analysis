# %%
import gzip
from bs4 import BeautifulSoup
import bs4
import pandas as pd
import numpy as np
import requests
import re

# %%
pd.options.display.max_columns = 60

# %%
# open and read gzipped xml file
infile = gzip.open('incidents.xml.gz')
content = infile.read()

# Transform content into Beautiful Soup for further processing
soup = BeautifulSoup(content, "lxml")
soup
# Out:
# <?xml version="1.0" encoding="UTF-8"?><html><body><soap:envelope xmlns:soap="http://schemas.xmlsoap.org/soap/envelope/"><soap:body><d2logicalmodel modelbaseversion="2" xmlns="http://datex2.eu/schema/2/2_0" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance"><exchange><supplieridentification><country>nl</country><nationalidentifier>NLNDW</nationalidentifier></supplieridentification><subscription><operatingmode>operatingMode3</operatingmode><subscriptionstarttime>2020-10-29T04:22:19.204Z</subscriptionstarttime><subscriptionstate>active</subscriptionstate><updatemethod>snapshot</updatemethod><target><address></address><protocol>HTTP</protocol></target></subscription></exchange><payloadpublication lang="nl" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:type="SituationPublication"><publicationtime>2020-12-17T16:44:50.449Z</publicationtime><publicationcreator><country>nl</country><nationalidentifier>NLNDW</nationalidentifier></publicationcreator><situation id="RWS03_956972" version="2"><overallseverity>unknown</overallseverity><situationversiontime>2020-12-17T15:33:15Z</situationversiontime><headerinformation><confidentiality>noRestriction</confidentiality><informationstatus>real</informationstatus></headerinformation><situationrecord id="RWS03_956972_1" version="2" xsi:type="VehicleObstruction"><situationrecordcreationreference>LCM-LCM20168480_IM_1</situationrecordcreationreference><situationrecordcreationtime>2020-12-17T15:33:15Z</situationrecordcreationtime><situationrecordobservationtime>2020-12-17T15:33:15Z</situationrecordobservationtime><situationrecordversiontime>2020-12-17T15:33:15Z</situationrecordversiontime><situationrecordfirstsupplierversiontime>2020-12-17T15:33:15Z</situationrecordfirstsupplierversiontime><probabilityofoccurrence>certain</probabilityofoccurrence><source><sourcename><values><value lang="nl">VC Noordwest-Nederland</value></values></sourcename></source><validity><validitystatus>active</validitystatus><validitytimespecification><overallstarttime>2020-12-17T15:32:36Z</overallstarttime></validitytimespecification></validity><groupoflocations xsi:type="Linear"><locationfordisplay><latitude>52.42696</latitude><longitude>4.682106</longitude></locationfordisplay><alertclinear xsi:type="AlertCMethod4Linear"><alertclocationcountrycode>8</alertclocationcountrycode><alertclocationtablenumber>5.21</alertclocationtablenumber><alertclocationtableversion>A</alertclocationtableversion><alertcdirection><alertcdirectioncoded>negative</alertcdirectioncoded></alertcdirection><alertcmethod4primarypointlocation><alertclocation><specificlocation>10589</specificlocation></alertclocation><offsetdistance><offsetdistance>1100</offsetdistance></offsetdistance></alertcmethod4primarypointlocation><alertcmethod4secondarypointlocation><alertclocation><specificlocation>10591</specificlocation></alertclocation><offsetdistance><offsetdistance>2400</offsetdistance></offsetdistance></alertcmethod4secondarypointlocation></alertclinear><linearextension><linearbycoordinatesextension><linearcoordinatesstartpoint><pointcoordinates><latitude>52.42696</latitude><longitude>4.682106</longitude></pointcoordinates></linearcoordinatesstartpoint><linearcoordinatesendpoint><pointcoordinates><latitude>52.42696</latitude><longitude>4.682106</longitude></pointcoordinates></linearcoordinatesendpoint></linearbycoordinatesextension></linearextension></groupoflocations><situationrecordextension><situationrecordextendedapproved><safetyrelatedmessage>true</safetyrelatedmessage></situationrecordextendedapproved></situationrecordextension><mobilityofobstruction><mobilitytype>stationary</mobilitytype></mobilityofobstruction><vehicleobstructiontype>brokenDownVehicle</vehicleobstructiontype></situationrecord></situation><situation id="RWS03_956973" version="2"><overallseverity>unknown</overallseverity><situationversiontime>2020-12-17T15:34:26Z</situationversiontime><headerinformation><confidentiality>noRestriction</confidentiality><informationstatus>real ...

# %%
# cdict = {'id':'RWS03_956972'}
# repos = soup.find_all('situation', cdict)
# repos

# %%
# List all tags of the file

tags = [tag.name for tag in soup.find_all()]
tags
# Out:
# ['html',
#  'body',
#  'soap:envelope',
#  'soap:body',
#  'd2logicalmodel',
#  'exchange',
#  'supplieridentification',
#  'country',
#  'nationalidentifier',
#  'subscription',
#  'operatingmode',
#  'subscriptionstarttime',
#  'subscriptionstate',
#  'updatemethod',
#  'target',
#  'address',
#  'protocol',
#  'payloadpublication',
#  'publicationtime',
#  'publicationcreator',
#  'country',
#  'nationalidentifier',
#  'situation',
#  'overallseverity',
#  'situationversiontime',
#  'headerinformation',
#  'confidentiality',
#  'informationstatus',
#  'situationrecord',
#  'situationrecordcreationreference',
#  'situationrecordcreationtime',
#  'situationrecordobservationtime',
#  'situationrecordversiontime',
#  'situationrecordfirstsupplierversiontime',
#  'probabilityofoccurrence',
#  'source',
#  'sourcename',
#  'values',
#  'value',
#  'validity',
#  'validitystatus',
#  'validitytimespecification',
#  'overallstarttime',
#  'groupoflocations',
#  'locationfordisplay',
#  'latitude',
#  'longitude',
#  'alertclinear',
#  'alertclocationcountrycode',
#  'alertclocationtablenumber',
#  'alertclocationtableversion',
#  'alertcdirection',
#  'alertcdirectioncoded',
#  'alertcmethod4primarypointlocation',
#  'alertclocation',
#  'specificlocation',
#  'offsetdistance',
#  'offsetdistance',
#  'alertcmethod4secondarypointlocation',
#  'alertclocation',
#  'specificlocation',
#  'offsetdistance',
#  'offsetdistance',
#  'linearextension',
#  'linearbycoordinatesextension',
#  'linearcoordinatesstartpoint',
#  'pointcoordinates',
#  'latitude',
#  'longitude',
#  'linearcoordinatesendpoint',
#  'pointcoordinates',
#  'latitude',
#  'longitude',
#  'situationrecordextension',
#  'situationrecordextendedapproved',
#  'safetyrelatedmessage',
#  'mobilityofobstruction',
#  'mobilitytype',
#  'vehicleobstructiontype',
#  'situation',
#  'overallseverity',
#  'situationversiontime',
#  'headerinformation',
#  'confidentiality',
#  'informationstatus',
#  'situationrecord',
#  'situationrecordcreationreference',
#  'situationrecordcreationtime',
#  'situationrecordobservationtime',
#  'situationrecordversiontime',
#  'situationrecordfirstsupplierversiontime',
#  'probabilityofoccurrence',
#  'source',
#  'sourcename',
#  'values',
#  'value',
#  'validity',
#  'validitystatus',
#  'validitytimespecification',
#  'overallstarttime',
#  'groupoflocations',
#  'locationfordisplay',
#  'latitude',
#  'longitude',
#  'alertclinear',
#  'alertclocationcountrycode',
#  'alertclocationtablenumber',
#  'alertclocationtableversion',
#  'alertcdirection',
#  'alertcdirectioncoded',
#  'alertcmethod4primarypointlocation',
#  'alertclocation',
#  'specificlocation',
#  'offsetdistance',
#  'offsetdistance',
#  'alertcmethod4secondarypointlocation',
#  'alertclocation',
#  'specificlocation',
#  'offsetdistance',
#  'offsetdistance',
#  'linearextension',
#  'linearbycoordinatesextension',
#  'linearcoordinatesstartpoint',
#  'pointcoordinates',
#  'latitude',
#  'longitude',
#  'linearcoordinatesendpoint',
#  'pointcoordinates',
#  'latitude',
#  'longitude',
#  'situationrecordextension',
#  'situationrecordextendedapproved',
#  'safetyrelatedmessage',
#  'mobilityofobstruction',
#  'mobilitytype',
#  'vehicleobstructiontype',
#  'situation',
#  'overallseverity',
#  'situationversiontime',
#  'headerinformation',
#  'confidentiality',
#  'informationstatus',
#  'situationrecord',
#  'situationrecordcreationreference',
#  'situationrecordcreationtime',
#  'situationrecordobservationtime',
#  'situationrecordversiontime',
#  'situationrecordfirstsupplierversiontime',
#  'probabilityofoccurrence',
#  'source',
#  'sourcename',
#  'values',
#  'value',
#  'validity',
#  'validitystatus',
#  'validitytimespecification',
#  'overallstarttime',
#  'groupoflocations',
#  'locationfordisplay',
#  'latitude',
#  'longitude',
#  'alertclinear',
#  'alertclocationcountrycode',
#  'alertclocationtablenumber',
#  'alertclocationtableversion',
#  'alertcdirection',
#  'alertcdirectioncoded',
#  'alertcmethod4primarypointlocation',
#  'alertclocation',
#  'specificlocation',
#  'offsetdistance',
#  'offsetdistance',
#  'alertcmethod4secondarypointlocation',
#  'alertclocation',
#  'specificlocation',
#  'offsetdistance',
#  'offsetdistance',
#  'linearextension',
#  'linearbycoordinatesextension',
#  'linearcoordinatesstartpoint',
#  'pointcoordinates',
#  'latitude',
#  'longitude',
#  'linearcoordinatesendpoint',
#  'pointcoordinates',
#  'latitude',
#  'longitude',
#  'situationrecordextension',
#  'situationrecordextendedapproved',
#  'safetyrelatedmessage',
#  'mobilityofobstruction',
#  'mobilitytype',
#  'vehicleobstructiontype',
#  'situation',
#  'overallseverity',
#  'situationversiontime',
#  'headerinformation',
#  'confidentiality',
#  'informationstatus',
#  'situationrecord',
#  'situationrecordcreationreference',
#  'situationrecordcreationtime',
#  'situationrecordobservationtime',
#  'situationrecordversiontime',
#  'situationrecordfirstsupplierversiontime',
#  'probabilityofoccurrence',
#  'source',
#  'sourcename',
#  'values',
#  'value',
#  'validity',
#  'validitystatus',
#  'validitytimespecification',
#  'overallstarttime',
#  'groupoflocations',
#  'locationfordisplay',
#  'latitude',
#  'longitude',
#  'alertclinear',
#  'alertclocationcountrycode',
#  'alertclocationtablenumber',
#  'alertclocationtableversion',
#  'alertcdirection',
#  'alertcdirectioncoded',
#  'alertcmethod4primarypointlocation',
#  'alertclocation',
#  'specificlocation',
#  'offsetdistance',
#  'offsetdistance',
#  'alertcmethod4secondarypointlocation',
#  'alertclocation',
#  'specificlocation',
#  'offsetdistance',
#  'offsetdistance',
#  'linearextension',
#  'linearbycoordinatesextension',
#  'linearcoordinatesstartpoint',
#  'pointcoordinates',
#  'latitude',
#  'longitude',
#  'linearcoordinatesendpoint',
#  'pointcoordinates',
#  'latitude',
#  'longitude',
#  'situationrecordextension',
#  'situationrecordextendedapproved',
#  'safetyrelatedmessage',
#  'mobilityofobstruction',
#  'mobilitytype',
#  'vehicleobstructiontype',
#  'situation',
#  'overallseverity',
#  'situationversiontime',
#  'headerinformation',
#  'confidentiality',
#  'informationstatus',
#  'situationrecord',
#  'situationrecordcreationreference',
#  'situationrecordcreationtime',
#  'situationrecordobservationtime',
#  'situationrecordversiontime',
#  'situationrecordfirstsupplierversiontime',
#  'probabilityofoccurrence',
#  'source',
#  'sourcename',
#  'values',
#  'value',
#  'validity',
#  'validitystatus',
#  'validitytimespecification',
#  'overallstarttime',
#  'groupoflocations',
#  'locationfordisplay',
#  'latitude',
#  'longitude',
#  'alertclinear',
#  'alertclocationcountrycode',
#  'alertclocationtablenumber',
#  'alertclocationtableversion',
#  'alertcdirection',
#  'alertcdirectioncoded',
#  'alertcmethod4primarypointlocation',
#  'alertclocation',
#  'specificlocation',
#  'offsetdistance',
#  'offsetdistance',
#  'alertcmethod4secondarypointlocation',
#  'alertclocation',
#  'specificlocation',
#  'offsetdistance',
#  'offsetdistance',
#  'linearextension',
#  'linearbycoordinatesextension',
#  'linearcoordinatesstartpoint',
#  'pointcoordinates',
#  'latitude',
#  'longitude',
#  'linearcoordinatesendpoint',
#  'pointcoordinates',
#  'latitude',
#  'longitude',
#  'mobilityofobstruction',
#  'mobilitytype',
#  'vehicleobstructiontype',
#  'situation',
#  'overallseverity',
#  'situationversiontime',
#  'headerinformation',
#  'confidentiality',
#  'informationstatus',
#  'situationrecord',
#  'situationrecordcreationreference',
#  'situationrecordcreationtime',
#  'situationrecordobservationtime',
#  'situationrecordversiontime',
#  'situationrecordfirstsupplierversiontime',
#  'probabilityofoccurrence',
#  'source',
#  'sourcename',
#  'values',
#  'value',
#  'validity',
#  'validitystatus',
#  'validitytimespecification',
#  'overallstarttime',
#  'groupoflocations',
#  'locationfordisplay',
#  'latitude',
#  'longitude',
#  'alertclinear',
#  'alertclocationcountrycode',
#  'alertclocationtablenumber',
#  'alertclocationtableversion',
#  'alertcdirection',
#  'alertcdirectioncoded',
#  'alertcmethod4primarypointlocation',
#  'alertclocation',
#  'specificlocation',
#  'offsetdistance',
#  'offsetdistance',
#  'alertcmethod4secondarypointlocation',
#  'alertclocation',
#  'specificlocation',
#  'offsetdistance',
#  'offsetdistance',
#  'linearextension',
#  'linearbycoordinatesextension',
#  'linearcoordinatesstartpoint',
#  'pointcoordinates',
#  'latitude',
#  'longitude',
#  'linearcoordinatesendpoint',
#  'pointcoordinates',
#  'latitude',
#  'longitude',
#  'situationrecordextension',
#  'situationrecordextendedapproved',
#  'safetyrelatedmessage',
#  'mobilityofobstruction',
#  'mobilitytype',
#  'vehicleobstructiontype',
#  'situation',
#  'overallseverity',
#  'situationversiontime',
#  'headerinformation',
#  'confidentiality',
#  'informationstatus',
#  'situationrecord',
#  'situationrecordcreationreference',
#  'situationrecordcreationtime',
#  'situationrecordobservationtime',
#  'situationrecordversiontime',
#  'situationrecordfirstsupplierversiontime',
#  'probabilityofoccurrence',
#  'source',
#  'sourcename',
#  'values',
#  'value',
#  'validity',
#  'validitystatus',
#  'validitytimespecification',
#  'overallstarttime',
#  'groupoflocations',
#  'locationfordisplay',
#  'latitude',
#  'longitude',
#  'alertclinear',
#  'alertclocationcountrycode',
#  'alertclocationtablenumber',
#  'alertclocationtableversion',
#  'alertcdirection',
#  'alertcdirectioncoded',
#  'alertcmethod4primarypointlocation',
#  'alertclocation',
#  'specificlocation',
#  'offsetdistance',
#  'offsetdistance',
#  'alertcmethod4secondarypointlocation',
#  'alertclocation',
#  'specificlocation',
#  'offsetdistance',
#  'offsetdistance',
#  'linearextension',
#  'linearbycoordinatesextension',
#  'linearcoordinatesstartpoint',
#  'pointcoordinates',
#  'latitude',
#  'longitude',
#  'linearcoordinatesendpoint',
#  'pointcoordinates',
#  'latitude',
#  'longitude',
#  'situationrecordextension',
#  'situationrecordextendedapproved',
#  'safetyrelatedmessage',
#  'mobilityofobstruction',
#  'mobilitytype',
#  'vehicleobstructiontype',
#  'situation',
#  'overallseverity',
#  'situationversiontime',
#  'headerinformation',
#  'confidentiality',
#  'informationstatus',
#  'situationrecord',
#  'situationrecordcreationreference',
#  'situationrecordcreationtime',
#  'situationrecordobservationtime',
#  'situationrecordversiontime',
#  'situationrecordfirstsupplierversiontime',
#  'probabilityofoccurrence',
#  'source',
#  'sourcename',
#  'values',
#  'value',
#  'validity',
#  'validitystatus',
#  'validitytimespecification',
#  'overallstarttime',
#  'groupoflocations',
#  'locationfordisplay',
#  'latitude',
#  'longitude',
#  'alertclinear',
#  'alertclocationcountrycode',
#  'alertclocationtablenumber',
#  'alertclocationtableversion',
#  'alertcdirection',
#  'alertcdirectioncoded',
#  'alertcmethod4primarypointlocation',
#  'alertclocation',
#  'specificlocation',
#  'offsetdistance',
#  'offsetdistance',
#  'alertcmethod4secondarypointlocation',
#  'alertclocation',
#  'specificlocation',
#  'offsetdistance',
#  'offsetdistance',
#  'linearextension',
#  'linearbycoordinatesextension',
#  'linearcoordinatesstartpoint',
#  'pointcoordinates',
#  'latitude',
#  'longitude',
#  'linearcoordinatesendpoint',
#  'pointcoordinates',
#  'latitude',
#  'longitude',
#  'situationrecordextension',
#  'situationrecordextendedapproved',
#  'safetyrelatedmessage',
#  'accidenttype',
#  'situation',
#  'overallseverity',
#  'situationversiontime',
#  'headerinformation',
#  'confidentiality',
#  'informationstatus',
#  'situationrecord',
#  'situationrecordcreationreference',
#  'situationrecordcreationtime',
#  'situationrecordobservationtime',
#  'situationrecordversiontime',
#  'situationrecordfirstsupplierversiontime',
#  'probabilityofoccurrence',
#  'source',
#  'sourcename',
#  'values',
#  'value',
#  'validity',
#  'validitystatus',
#  'validitytimespecification',
#  'overallstarttime',
#  'groupoflocations',
#  'locationfordisplay',
#  'latitude',
#  'longitude',
#  'alertclinear',
#  'alertclocationcountrycode',
#  'alertclocationtablenumber',
#  'alertclocationtableversion',
#  'alertcdirection',
#  'alertcdirectioncoded',
#  'alertcmethod4primarypointlocation',
#  'alertclocation',
#  'specificlocation',
#  'offsetdistance',
#  'offsetdistance',
#  'alertcmethod4secondarypointlocation',
#  'alertclocation',
#  'specificlocation',
#  'offsetdistance',
#  'offsetdistance',
#  'linearextension',
#  'linearbycoordinatesextension',
#  'linearcoordinatesstartpoint',
#  'pointcoordinates',
#  'latitude',
#  'longitude',
#  'linearcoordinatesendpoint',
#  'pointcoordinates',
#  'latitude',
#  'longitude',
#  'situationrecordextension',
#  'situationrecordextendedapproved',
#  'safetyrelatedmessage',
#  'mobilityofobstruction',
#  'mobilitytype',
#  'vehicleobstructiontype',
#  'situation',
#  'overallseverity',
#  'situationversiontime',
#  'headerinformation',
#  'confidentiality',
#  'informationstatus',
#  'situationrecord',
#  'situationrecordcreationreference',
#  'situationrecordcreationtime',
#  'situationrecordobservationtime',
#  'situationrecordversiontime',
#  'situationrecordfirstsupplierversiontime',
#  'probabilityofoccurrence',
#  'source',
#  'sourcename',
#  'values',
#  'value',
#  'validity',
#  'validitystatus',
#  'validitytimespecification',
#  'overallstarttime',
#  'groupoflocations',
#  'locationfordisplay',
#  'latitude',
#  'longitude',
#  'alertclinear',
#  'alertclocationcountrycode',
#  'alertclocationtablenumber',
#  'alertclocationtableversion',
#  'alertcdirection',
#  'alertcdirectioncoded',
#  'alertcmethod4primarypointlocation',
#  'alertclocation',
#  'specificlocation',
#  'offsetdistance',
#  'offsetdistance',
#  'alertcmethod4secondarypointlocation',
#  'alertclocation',
#  'specificlocation',
#  'offsetdistance',
#  'offsetdistance',
#  'linearextension',
#  'linearbycoordinatesextension',
#  'linearcoordinatesstartpoint',
#  'pointcoordinates',
#  'latitude',
#  'longitude',
#  'linearcoordinatesendpoint',
#  'pointcoordinates',
#  'latitude',
#  'longitude',
#  'situationrecordextension',
#  'situationrecordextendedapproved',
#  'safetyrelatedmessage',
#  'mobilityofobstruction',
#  'mobilitytype',
#  'vehicleobstructiontype',
#  'situation',
#  'overallseverity',
#  'situationversiontime',
#  'headerinformation',
#  'confidentiality',
#  'informationstatus',
#  'situationrecord',
#  'situationrecordcreationreference',
#  'situationrecordcreationtime',
#  'situationrecordobservationtime',
#  'situationrecordversiontime',
#  'situationrecordfirstsupplierversiontime',
#  'probabilityofoccurrence',
#  'source',
#  'sourcename',
#  'values',
#  'value',
#  'validity',
#  'validitystatus',
#  'validitytimespecification',
#  'overallstarttime',
#  'groupoflocations',
#  'locationfordisplay',
#  'latitude',
#  'longitude',
#  'alertclinear',
#  'alertclocationcountrycode',
#  'alertclocationtablenumber',
#  'alertclocationtableversion',
#  'alertcdirection',
#  'alertcdirectioncoded',
#  'alertcmethod4primarypointlocation',
#  'alertclocation',
#  'specificlocation',
#  'offsetdistance',
#  'offsetdistance',
#  'alertcmethod4secondarypointlocation',
#  'alertclocation',
#  'specificlocation',
#  'offsetdistance',
#  'offsetdistance',
#  'linearextension',
#  'linearbycoordinatesextension',
#  'linearcoordinatesstartpoint',
#  'pointcoordinates',
#  'latitude',
#  'longitude',
#  'linearcoordinatesendpoint',
#  'pointcoordinates',
#  'latitude',
#  'longitude',
#  'situationrecordextension',
#  'situationrecordextendedapproved',
#  'safetyrelatedmessage',
#  'mobilityofobstruction',
#  'mobilitytype',
#  'vehicleobstructiontype',
#  'situation',
#  'overallseverity',
#  'situationversiontime',
#  'headerinformation',
#  'confidentiality',
#  'informationstatus',
#  'situationrecord',
#  'situationrecordcreationreference',
#  'situationrecordcreationtime',
#  'situationrecordobservationtime',
#  'situationrecordversiontime',
#  'situationrecordfirstsupplierversiontime',
#  'probabilityofoccurrence',
#  'source',
#  'sourcename',
#  'values',
#  'value',
#  'validity',
#  'validitystatus',
#  'validitytimespecification',
#  'overallstarttime',
#  'groupoflocations',
#  'locationfordisplay',
#  'latitude',
#  'longitude',
#  'alertclinear',
#  'alertclocationcountrycode',
#  'alertclocationtablenumber',
#  'alertclocationtableversion',
#  'alertcdirection',
#  'alertcdirectioncoded',
#  'alertcmethod4primarypointlocation',
#  'alertclocation',
#  'specificlocation',
#  'offsetdistance',
#  'offsetdistance',
#  'alertcmethod4secondarypointlocation',
#  'alertclocation',
#  'specificlocation',
#  'offsetdistance',
#  'offsetdistance',
#  'linearextension',
#  'linearbycoordinatesextension',
#  'linearcoordinatesstartpoint',
#  'pointcoordinates',
#  'latitude',
#  'longitude',
#  'linearcoordinatesendpoint',
#  'pointcoordinates',
#  'latitude',
#  'longitude',
#  'situationrecordextension',
#  'situationrecordextendedapproved',
#  'safetyrelatedmessage',
#  'mobilityofobstruction',
#  'mobilitytype',
#  'vehicleobstructiontype',
#  'situation',
#  'overallseverity',
#  'situationversiontime',
#  'headerinformation',
#  'confidentiality',
#  'informationstatus',
#  'situationrecord',
#  'situationrecordcreationreference',
#  'situationrecordcreationtime',
#  'situationrecordobservationtime',
#  'situationrecordversiontime',
#  'situationrecordfirstsupplierversiontime',
#  'probabilityofoccurrence',
#  'source',
#  'sourcename',
#  'values',
#  'value',
#  'validity',
#  'validitystatus',
#  'validitytimespecification',
#  'overallstarttime',
#  'groupoflocations',
#  'locationfordisplay',
#  'latitude',
#  'longitude',
#  'alertclinear',
#  'alertclocationcountrycode',
#  'alertclocationtablenumber',
#  'alertclocationtableversion',
#  'alertcdirection',
#  'alertcdirectioncoded',
#  'alertcmethod4primarypointlocation',
#  'alertclocation',
#  'specificlocation',
#  'offsetdistance',
#  'offsetdistance',
#  'alertcmethod4secondarypointlocation',
#  'alertclocation',
#  'specificlocation',
#  'offsetdistance',
#  'offsetdistance',
#  'linearextension',
#  'linearbycoordinatesextension',
#  'linearcoordinatesstartpoint',
#  'pointcoordinates',
#  'latitude',
#  'longitude',
#  'linearcoordinatesendpoint',
#  'pointcoordinates',
#  'latitude',
#  'longitude',
#  'situationrecordextension',
#  'situationrecordextendedapproved',
#  'safetyrelatedmessage',
#  'mobilityofobstruction',
#  'mobilitytype',
#  'vehicleobstructiontype',
#  'situation',
#  'overallseverity',
#  'situationversiontime',
#  'headerinformation',
#  'confidentiality',
#  'informationstatus',
#  'situationrecord',
#  'situationrecordcreationreference',
#  'situationrecordcreationtime',
#  'situationrecordobservationtime',
#  'situationrecordversiontime',
#  'situationrecordfirstsupplierversiontime',
#  'probabilityofoccurrence',
#  'source',
#  'sourcename',
#  'values',
#  'value',
#  'validity',
#  'validitystatus',
#  'validitytimespecification',
#  'overallstarttime',
#  'groupoflocations',
#  'locationfordisplay',
#  'latitude',
#  'longitude',
#  'alertclinear',
#  'alertclocationcountrycode',
#  'alertclocationtablenumber',
#  'alertclocationtableversion',
#  'alertcdirection',
#  'alertcdirectioncoded',
#  'alertcmethod4primarypointlocation',
#  'alertclocation',
#  'specificlocation',
#  'offsetdistance',
#  'offsetdistance',
#  'alertcmethod4secondarypointlocation',
#  'alertclocation',
#  'specificlocation',
#  'offsetdistance',
#  'offsetdistance',
#  'linearextension',
#  'linearbycoordinatesextension',
#  'linearcoordinatesstartpoint',
#  'pointcoordinates',
#  'latitude',
#  'longitude',
#  'linearcoordinatesendpoint',
#  'pointcoordinates',
#  'latitude',
#  'longitude',
#  'situationrecordextension',
#  'situationrecordextendedapproved',
#  'safetyrelatedmessage',
#  'mobilityofobstruction',
#  'mobilitytype',
#  'vehicleobstructiontype',
#  'situation',
#  'overallseverity',
#  'situationversiontime',
#  'headerinformation',
#  'confidentiality',
#  'informationstatus',
#  'situationrecord',
#  'situationrecordcreationreference',
#  'situationrecordcreationtime',
#  'situationrecordobservationtime',
#  'situationrecordversiontime',
#  'situationrecordfirstsupplierversiontime',
#  'probabilityofoccurrence',
#  'source',
#  'sourcename',
#  'values',
#  'value',
#  'validity',
#  'validitystatus',
#  'validitytimespecification',
#  'overallstarttime',
#  'groupoflocations',
#  'locationfordisplay',
#  'latitude',
#  'longitude',
#  'alertclinear',
#  'alertclocationcountrycode',
#  'alertclocationtablenumber',
#  'alertclocationtableversion',
#  'alertcdirection',
#  'alertcdirectioncoded',
#  'alertcmethod4primarypointlocation',
#  'alertclocation',
#  'specificlocation',
#  'offsetdistance',
#  'offsetdistance',
#  'alertcmethod4secondarypointlocation',
#  'alertclocation',
#  'specificlocation',
#  'offsetdistance',
#  'offsetdistance',
#  'linearextension',
#  'linearbycoordinatesextension',
#  'linearcoordinatesstartpoint',
#  'pointcoordinates',
#  'latitude',
#  'longitude',
#  'linearcoordinatesendpoint',
#  'pointcoordinates',
#  'latitude',
#  'longitude',
#  'situationrecordextension',
#  'situationrecordextendedapproved',
#  'safetyrelatedmessage',
#  'accidenttype',
#  'situation',
#  'overallseverity',
#  'situationversiontime',
#  'headerinformation',
#  'confidentiality',
#  'informationstatus',
#  'situationrecord',
#  'situationrecordcreationreference',
#  'situationrecordcreationtime',
#  'situationrecordobservationtime',
#  'situationrecordversiontime',
#  'situationrecordfirstsupplierversiontime',
#  'probabilityofoccurrence',
#  'source',
#  'sourcename',
#  'values',
#  'value',
#  'validity',
#  'validitystatus',
#  'validitytimespecification',
#  'overallstarttime',
#  'groupoflocations',
#  'locationfordisplay',
#  'latitude',
#  'longitude',
#  'alertclinear',
#  'alertclocationcountrycode',
#  'alertclocationtablenumber',
#  'alertclocationtableversion',
#  'alertcdirection',
#  'alertcdirectioncoded',
#  'alertcmethod4primarypointlocation',
#  'alertclocation',
#  'specificlocation',
#  'offsetdistance',
#  'offsetdistance',
#  'alertcmethod4secondarypointlocation',
#  'alertclocation',
#  'specificlocation',
#  'offsetdistance',
#  'offsetdistance',
#  'linearextension',
#  'linearbycoordinatesextension',
#  'linearcoordinatesstartpoint',
#  'pointcoordinates',
#  'latitude',
#  'longitude',
#  'linearcoordinatesendpoint',
#  'pointcoordinates',
#  'latitude',
#  'longitude',
#  'situationrecordextension',
#  'situationrecordextendedapproved',
#  'safetyrelatedmessage',
#  'mobilityofobstruction',
#  'mobilitytype',
#  'vehicleobstructiontype',
#  'situation',
#  'overallseverity',
#  'situationversiontime',
#  'headerinformation',
#  'confidentiality',
#  'informationstatus',
#  'situationrecord',
#  'situationrecordcreationreference',
#  'situationrecordcreationtime',
#  'situationrecordobservationtime',
#  'situationrecordversiontime',
#  'situationrecordfirstsupplierversiontime',
#  'probabilityofoccurrence',
#  'source',
#  'sourcename',
#  'values',
#  'value',
#  'validity',
#  'validitystatus',
#  'validitytimespecification',
#  'overallstarttime',
#  'groupoflocations',
#  'locationfordisplay',
#  'latitude',
#  'longitude',
#  'alertcpoint',
#  'alertclocationcountrycode',
#  'alertclocationtablenumber',
#  'alertclocationtableversion',
#  'alertcdirection',
#  'alertcdirectioncoded',
#  'alertcmethod4primarypointlocation',
#  'alertclocation',
#  'specificlocation',
#  'offsetdistance',
#  'offsetdistance',
#  'pointbycoordinates',
#  'pointcoordinates',
#  'latitude',
#  'longitude',
#  'situationrecordextension',
#  'situationrecordextendedapproved',
#  'safetyrelatedmessage',
#  'mobilityofobstruction',
#  'mobilitytype',
#  'vehicleobstructiontype',
#  'situation',
#  'overallseverity',
#  'situationversiontime',
#  'headerinformation',
#  'confidentiality',
#  'informationstatus',
#  'situationrecord',
#  'situationrecordcreationreference',
#  'situationrecordcreationtime',
#  'situationrecordobservationtime',
#  'situationrecordversiontime',
#  'situationrecordfirstsupplierversiontime',
#  'probabilityofoccurrence',
#  'source',
#  'sourcename',
#  'values',
#  'value',
#  'validity',
#  'validitystatus',
#  'validitytimespecification',
#  'overallstarttime',
#  'groupoflocations',
#  'locationfordisplay',
#  'latitude',
#  'longitude',
#  'alertclinear',
#  'alertclocationcountrycode',
#  ...]

# %%
# Work-around to find content of 'situation' tag

indices = [i for i, x in enumerate(tags) if x == "situation"]
print(indices)
for i in range(len(indices)-1):
    print(indices[i+1]-indices[i])
# Out:
# [22, 79, 136, 193, 250, 304, 361, 418, 473, 530, 587, 644, 701, 758, 815, 870, 927, 973, 1030, 1087, 1142, 1185, 1242, 1286, 1343, 1389, 1446, 1492, 1549, 1606, 1661, 1718, 1775, 1827, 1873, 1930, 1987, 2041, 2098, 2138, 2195, 2252, 2309, 2366, 2407, 2464, 2508, 2563]
# 57
# 57
# 57
# 57
# 54
# 57
# 57
# 55
# 57
# 57
# 57
# 57
# 57
# 57
# 55
# 57
# 46
# 57
# 57
# 55
# 43
# 57
# 44
# 57
# 46
# 57
# 46
# 57
# 57
# 55
# 57
# 57
# 52
# 46
# 57
# 57
# 54
# 57
# 40
# 57
# 57
# 57
# 57
# 41
# 57
# 44
# 55

# %%
# There are 48 situations with different number of tags within each. The first situation starts from tag 22.

situation_tags = set(tags[22:])
situation_tags
# Out:
# {'accidenttype',
#  'administrativearea',
#  'alertcdirection',
#  'alertcdirectioncoded',
#  'alertclinear',
#  'alertclocation',
#  'alertclocationcountrycode',
#  'alertclocationtablenumber',
#  'alertclocationtableversion',
#  'alertcmethod4primarypointlocation',
#  'alertcmethod4secondarypointlocation',
#  'alertcpoint',
#  'confidentiality',
#  'groupoflocations',
#  'headerinformation',
#  'informationstatus',
#  'latitude',
#  'linearbycoordinatesextension',
#  'linearcoordinatesendpoint',
#  'linearcoordinatesstartpoint',
#  'linearextension',
#  'locationfordisplay',
#  'longitude',
#  'mobilityofobstruction',
#  'mobilitytype',
#  'obstructiontype',
#  'offsetdistance',
#  'overallseverity',
#  'overallstarttime',
#  'pointbycoordinates',
#  'pointcoordinates',
#  'pointextension',
#  'probabilityofoccurrence',
#  'roadname',
#  'roadsidereferencepoint',
#  'roadsidereferencepointidentifier',
#  'safetyrelatedmessage',
#  'situation',
#  'situationrecord',
#  'situationrecordcreationreference',
#  'situationrecordcreationtime',
#  'situationrecordextendedapproved',
#  'situationrecordextension',
#  'situationrecordfirstsupplierversiontime',
#  'situationrecordobservationtime',
#  'situationrecordversiontime',
#  'situationversiontime',
#  'source',
#  'sourcename',
#  'specificlocation',
#  'validity',
#  'validitystatus',
#  'validitytimespecification',
#  'value',
#  'values',
#  'vehicleobstructiontype'}

# %%
# Ids of each situation in the file

ids = [tag['id'] for tag in soup.select('situation[id]')]
ids
# Out:
# ['RWS03_956972',
#  'RWS03_956973',
#  'RWS03_956974',
#  'RWS03_956975',
#  'RWS03_956976',
#  'RWS03_956977',
#  'RWS03_956978',
#  'RWS03_956979',
#  'RWS03_956970',
#  'RWS03_956971',
#  'RWS03_956983',
#  'RWS03_956984',
#  'RWS03_956985',
#  'RWS03_956986',
#  'RWS03_956987',
#  'RWS03_956988',
#  'RWS03_956989',
#  'RWS03_956980',
#  'RWS03_956981',
#  'RWS03_956982',
#  'RWS03_956554',
#  'RWS03_957005',
#  'RWS03_957006',
#  'RWS03_957007',
#  'RWS03_957008',
#  'RWS03_957009',
#  'RWS03_957000',
#  'RWS03_957001',
#  'RWS03_957002',
#  'RWS03_957003',
#  'RWS03_957004',
#  'RWS03_957017',
#  'RWS03_956967',
#  'RWS03_957010',
#  'RWS03_957011',
#  'RWS03_957012',
#  'RWS03_957013',
#  'RWS03_957014',
#  'RWS03_957015',
#  'RWS03_956994',
#  'RWS03_956995',
#  'RWS03_956996',
#  'RWS03_956997',
#  'RWS03_956999',
#  'RWS03_956990',
#  'RWS03_956991',
#  'RWS03_956992',
#  'RWS03_956993']

# %%
cdict = {'id':'RWS03_956972'}
situation = soup.find_all('situation', cdict)
childs = [tag.name for tag in situation[0].find_all()]
childs
# Out:
# ['overallseverity',
#  'situationversiontime',
#  'headerinformation',
#  'confidentiality',
#  'informationstatus',
#  'situationrecord',
#  'situationrecordcreationreference',
#  'situationrecordcreationtime',
#  'situationrecordobservationtime',
#  'situationrecordversiontime',
#  'situationrecordfirstsupplierversiontime',
#  'probabilityofoccurrence',
#  'source',
#  'sourcename',
#  'values',
#  'value',
#  'validity',
#  'validitystatus',
#  'validitytimespecification',
#  'overallstarttime',
#  'groupoflocations',
#  'locationfordisplay',
#  'latitude',
#  'longitude',
#  'alertclinear',
#  'alertclocationcountrycode',
#  'alertclocationtablenumber',
#  'alertclocationtableversion',
#  'alertcdirection',
#  'alertcdirectioncoded',
#  'alertcmethod4primarypointlocation',
#  'alertclocation',
#  'specificlocation',
#  'offsetdistance',
#  'offsetdistance',
#  'alertcmethod4secondarypointlocation',
#  'alertclocation',
#  'specificlocation',
#  'offsetdistance',
#  'offsetdistance',
#  'linearextension',
#  'linearbycoordinatesextension',
#  'linearcoordinatesstartpoint',
#  'pointcoordinates',
#  'latitude',
#  'longitude',
#  'linearcoordinatesendpoint',
#  'pointcoordinates',
#  'latitude',
#  'longitude',
#  'situationrecordextension',
#  'situationrecordextendedapproved',
#  'safetyrelatedmessage',
#  'mobilityofobstruction',
#  'mobilitytype',
#  'vehicleobstructiontype']

# %%
for i in ids:
    cdict = {'id':i}
    situation = soup.find_all('situation', cdict)
    childs = [tag.name for tag in situation[0].find_all()]

# %%
# Present each situation as a separate dataframe and collect all dataframes in a list

df_list = []
for id_code in ids:
    cdict = {'id':id_code}
    situation = soup.find_all('situation', cdict)
    childs = [tag.name for tag in situation[0].find_all()]
    
    situation_dict = {'situation_id':id_code}

    for tag in childs:
        situation_dict[tag] = situation[0].find_all(tag)[0].next

    df_list.append(pd.DataFrame.from_dict(situation_dict, orient='index'))

# %%
# Aggreage all situations in one dataframe

df = pd.concat(df_list, axis=1).transpose().reset_index().drop('index', axis=1)

# %%
# Drop duplicated columns

to_drop = ['headerinformation','situationrecord','source', 'sourcename', 'values', 'validity', 'validitytimespecification',
          'groupoflocations', 'locationfordisplay', 'alertclinear', 'alertcdirection', 'alertcmethod4primarypointlocation',
          'alertclocation', 'linearextension', 'linearbycoordinatesextension', 'situationrecordextension',
          'situationrecordextendedapproved', 'mobilityofobstruction', 'pointextension', 'roadsidereferencepoint',
          'roadsidereferencepointidentifier', 'administrativearea', 'roadname', 'obstructiontype',
          'situationrecordobservationtime', 'situationrecordversiontime','linearcoordinatesstartpoint', 'pointcoordinates',
           'linearcoordinatesendpoint']
df.drop(to_drop, axis=1, inplace=True)

# %% [markdown]
# ### Extract content of all tags within the dataframe

# %%
type(df['offsetdistance'][0]) == bs4.element.Tag
# Out:
# True

# %%
df['offsetdistance'][0].contents[0]
# Out:
# '1100'

# %%
def extract_content(line):
    if type(line) == bs4.element.Tag:
        if type(line.contents[0]) == bs4.element.Tag:
            return line.contents[0].contents[0]
        else:
            return line.contents[0]
    else:
        return line
    
extract_content(df['offsetdistance'][0])
# extract_content(df.iloc[38], 'offsetdistance')
# Out:
# '1100'

# %%
for col in df.columns:
    if df[col].apply(lambda x: type(x) == bs4.element.Tag).any():
        print(col)
        df[col] = df[col].apply(lambda row: extract_content(row))
# Out:
# offsetdistance
# alertcmethod4secondarypointlocation
# alertcpoint
# pointbycoordinates

# %%
df
# Out:
#     situation_id overallseverity  situationversiontime confidentiality  \
# 0   RWS03_956972         unknown  2020-12-17T15:33:15Z   noRestriction
# 1   RWS03_956973         unknown  2020-12-17T15:34:26Z   noRestriction
# 2   RWS03_956974         unknown  2020-12-17T15:36:05Z   noRestriction
# 3   RWS03_956975         unknown  2020-12-17T15:36:47Z   noRestriction
# 4   RWS03_956976         unknown  2020-12-17T15:40:18Z   noRestriction
# 5   RWS03_956977         unknown  2020-12-17T15:40:59Z   noRestriction
# 6   RWS03_956978         unknown  2020-12-17T15:44:50Z   noRestriction
# 7   RWS03_956979         unknown  2020-12-17T15:46:11Z   noRestriction
# 4               real             LCM-LCM20168484_IM_1
# 5               real             LCM-LCM20168485_IM_1
# 6               real             LCM-LCM20168486_IM_1
# 7               real             LCM-LCM20168488_IM_1
# 8               real             LCM-LCM20168478_IM_1
# 9               real             LCM-LCM20168479_IM_1
# 10              real             LCM-LCM20168492_IM_1
# 11              real             LCM-LCM20168494_IM_1
# 12              real             LCM-LCM20168495_IM_1
# 13              real             LCM-LCM20168493_IM_1
# 14              real             LCM-LCM20168496_IM_1
# 15              real             LCM-LCM20168499_IM_1
# 16              real             LCM-LCM20168503_IM_1
# 17              real             LCM-LCM20168489_IM_1
# 18              real             LCM-LCM20168490_IM_1
# 19              real             LCM-LCM20168491_IM_1
# 20              real              EUX-CMVCNL4474496_1
# 21              real             LCM-LCM20168523_IM_1
# 22              real             LCM-LCM20168524_IM_1
# 23              real             LCM-LCM20168526_IM_1
# 24              real             LCM-LCM20168527_IM_1
# 25              real             LCM-LCM20168525_IM_1
# 26              real             LCM-LCM20168517_IM_1
# 27              real             LCM-LCM20168518_IM_1
# 28              real             LCM-LCM20168520_IM_1
# 29              real             LCM-LCM20168521_IM_1
# 30              real             LCM-LCM20168522_IM_1
# 31              real             LCM-LCM20168533_IM_1
# 32              real              EUX-CMVCNL4475001_1
# 33              real             LCM-LCM20168528_IM_1
# 34              real             LCM-LCM20168529_IM_1
# 35              real              EUX-CMVCNL4475034_1
# 36              real             LCM-LCM20168530_IM_1
# 37              real              EUX-CMVCNL4475029_1
# 38              real             LCM-LCM20168531_IM_1
# 39              real              EUX-CMVCNL4475017_1
# 40              real             LCM-LCM20168510_IM_1
# 41              real             LCM-LCM20168513_IM_1
# 42              real             LCM-LCM20168514_IM_1
# 43              real             LCM-LCM20168516_IM_1
# 44              real             LCM-LCM20168502_IM_1
# 45              real             LCM-LCM20168497_IM_1
# 46              real             LCM-LCM20168504_IM_1
# 47              real             LCM-LCM20168507_IM_1
#
#    situationrecordcreationtime situationrecordfirstsupplierversiontime  \
# 0         2020-12-17T15:33:15Z                    2020-12-17T15:33:15Z
# 1         2020-12-17T15:34:26Z                    2020-12-17T15:34:26Z
# 2         2020-12-17T15:36:05Z                    2020-12-17T15:35:56Z
# 3         2020-12-17T15:36:47Z                    2020-12-17T15:36:47Z
# 4         2020-12-17T15:40:18Z                    2020-12-17T15:40:17Z
# 5         2020-12-17T15:40:59Z                    2020-12-17T15:40:58Z
# 6         2020-12-17T15:44:50Z                    2020-12-17T15:44:50Z
# 7         2020-12-17T15:46:11Z                    2020-12-17T15:46:10Z
# 8         2020-12-17T15:30:24Z                    2020-12-17T15:30:23Z
# 9         2020-12-17T15:32:15Z                    2020-12-17T15:32:14Z
# 10        2020-12-17T15:51:54Z                    2020-12-17T15:51:54Z
# 11        2020-12-17T15:55:35Z                    2020-12-17T15:55:35Z
# 12        2020-12-17T15:55:56Z                    2020-12-17T15:55:55Z
# 13        2020-12-17T15:56:37Z                    2020-12-17T15:56:36Z
# 14        2020-12-17T15:56:48Z                    2020-12-17T15:56:47Z
# 15        2020-12-17T15:58:29Z                    2020-12-17T15:58:28Z
# 16        2020-12-17T16:01:30Z                    2020-12-17T16:01:29Z
# 30         active  2020-12-17T16:27:23Z       51.52316      5.223938
# 31         active  2020-12-17T16:44:17Z       51.82894      4.765049
# 32         active  2020-12-17T15:19:05Z  53.2024241994  6.5522762678
# 33         active  2020-12-17T16:37:11Z       52.09242    5.17450857
# 34         active  2020-12-17T16:39:22Z       52.06467      4.805853
# 35         active  2020-12-17T16:39:53Z  52.2981607848  6.9665837292
# 36         active  2020-12-17T16:39:33Z       52.74441    6.81517935
# 37         active  2020-12-17T16:41:37Z  51.9403959772  5.0046939548
# 38         active  2020-12-17T16:40:49Z      52.570034    6.63314772
# 39         active  2020-12-17T16:11:07Z  52.3411749327  6.5947832974
# 40         active  2020-12-17T16:11:58Z       52.94539    6.53994656
# 41         active  2020-12-17T16:13:14Z       52.04755    4.35770226
# 42         active  2020-12-17T16:14:10Z     52.1601563      4.991612
# 43         active  2020-12-17T16:16:03Z     51.9802437      5.570764
# 44         active  2020-12-17T16:00:52Z       52.06614      4.779302
# 45         active  2020-12-17T15:57:31Z     51.5264359      5.390266
# 46         active  2020-12-17T16:01:43Z     51.8647842      4.544869
# 47         active  2020-12-17T16:08:50Z     51.9403954      5.004694
#
#    alertclocationcountrycode alertclocationtablenumber  \
# 0                          8                      5.21
# 1                          8                      5.21
# 2                          8                      5.21
# 3                          8                      5.21
# 4                          8                      5.21
# 5                          8                      5.21
# 6                          8                      5.21
# 7                          8                      5.21
# 8                          8                      5.21
# 9                          8                      5.21
# 10                         8                      5.21
# 11                         8                      5.21
# 12                         8                      5.21
# 13                         8                      5.21
# 14                         8                      5.21
# 15                         8                      5.21
# 16                         8                      5.21
# 17                         8                      5.21
# 18                         8                      5.21
# 19                         8                      5.21
# 20                         8                      5.21
# 21                         8                      5.21
# 22                         8                      5.21
# 23                         8                      5.21
# 24                         8                      5.21
# 25                         8                      5.21
# 26                         8                      5.21
# 27                         8                      5.21
# 28                         8                      5.21
# 29                         8                      5.21
# 30                         8                      5.21
# 31                         8                      5.21
# 32                         8                      5.21
# 33                         8                      5.21
# 34                         8                      5.21
# 35                         8                      5.21
# 36                         8                      5.21
# 37                         8                      5.21
# 38                       NaN                       NaN
# 39                         8                      5.21
# 40                         8                      5.21
# 41                         8                      5.21
# 42                         8                      5.21
# 43                         8                      5.21
# 44                         8                      5.21
# 45                         8                      5.21
# 46                         8                      5.21
# 47                         8                      5.21
#
#    alertclocationtableversion alertcdirectioncoded specificlocation  \
# 0                           A             negative            10589
# 1                           A             negative             7609
# 2                           A             positive             8353
# 3                           A             positive             8334
# 4                           A             negative             8862
# 5                           A             positive            10659
# 6                           A             negative             7263
# 7                           A             negative             8343
# 8                           A             positive             7284
# 9                           A             negative             9150
# 10                          A             positive             8513
# 11                          A             positive             8316
# 12                          A             positive             7627
# 13                          A             negative            22287
# 14                          A             negative             9155
# 15                          A             negative            22288
# 16                          A             negative             7004
# 17                          A             positive            10566
# 18                          A             negative            10019
# 19                          A             positive             8353
# 20                          A             negative            14189
# 21                          A             negative             9205
# 22                          A             positive             7433
# 23                          A             positive             8004
# 24                          A             positive             7293
# 25                          A             positive             7201
# 26                          A             negative             7448
# 27                          A             negative             7276
# 28                          A             negative             8099
# 29                          A             positive             7201
# 30                          A             positive             9647
# 31                          A             negative             7461
# 32                          A             negative            14970
# 33                          A             positive             8460
# 34                          A             negative             7276
# 35                          A             positive             7125
# 36                          A             negative            13929
# 37                          A             negative             8327
# 38                        NaN                  NaN              NaN
# 39                          A             negative             9026
# 40                          A             negative             8561
# 41                          A             positive             9202
# 42                          A             positive             7999
# 43                          A             positive            11498
# 44                          A             negative             7276
# 45                          A             negative             7934
# 46                          A             positive             7448
# 47                          A             negative             8327
#
#    offsetdistance alertcmethod4secondarypointlocation safetyrelatedmessage  \
# 0            1100                               10591                 true
# 1           17600                                7623                 true
# 2            3200                                8347                 true
# 3            4800                                8330                 true
# 4            2300                                8865                  NaN
# 5            3800                               10665                 true
# 6            2000                                7265                 true
# 7            1500                                8347                 true
# 8           49700                                7255                 true
# 9            3900                                9154                 true
# 10          34400                                8478                 true
# 11           1600                                8315                 true
# 12           2200                                7625                 true
# 13           2100                               22288                 true
# 14           1200                                9158                 true
# 15            300                                9190                 true
# 16            500                                 NaN                 true
# 17           7100                               10561                 true
# 18           1500                               21883                 true
# 19           4000                                8347                 true
# 20            100                                 NaN                  NaN
# 21           2100                                9208                 true
# 22            900                                 NaN                 true
# 23          25600                                7988                 true
# 24           1100                                 NaN                 true
# 25           3200                                7193                 true
# 26           1300                                 NaN                 true
# 27           4000                                7277                 true
# 28           2300                                8101                 true
# 29           1300                                7193                 true
# 30           5800                                9643                 true
# 31           1800                                7463                 true
# 32            200                               14971                  NaN
# 33            300                                 NaN                 true
# 34           4800                                7277                 true
# 35           3800                                7119                 true
# 36           3500                               13930                  NaN
# 37           5400                                8330                 true
# 38            NaN                                 NaN                  NaN
# 39           7900                                9018                 true
# 40           6100                               22264                 true
# 41           3100                                9196                 true
# 42           2000                                7996                 true
# 43              0                                 NaN                  NaN
# 44           3000                                7277                 true
# 45            600                                 NaN                 true
# 46           2200                               22528                 true
# 47           5400                                8330                 true
#
#    mobilitytype vehicleobstructiontype                   accidenttype  \
# 0    stationary      brokenDownVehicle                            NaN
# 1    stationary      brokenDownVehicle                            NaN
# 2    stationary   brokenDownHeavyLorry                            NaN
# 3    stationary      brokenDownVehicle                            NaN
# 4    stationary      brokenDownVehicle                            NaN
# 5    stationary      brokenDownVehicle                            NaN
# 6    stationary      brokenDownVehicle                            NaN
# 7           NaN                    NaN                       accident
# 8    stationary      brokenDownVehicle                            NaN
# 9    stationary      brokenDownVehicle                            NaN
# 10   stationary      brokenDownVehicle                            NaN
# 11   stationary      brokenDownVehicle                            NaN
# 12   stationary      brokenDownVehicle                            NaN
# 13   stationary      brokenDownVehicle                            NaN
# 14          NaN                    NaN                       accident
# 15   stationary      brokenDownVehicle                            NaN
# 16   stationary      brokenDownVehicle                            NaN
# 17   stationary      brokenDownVehicle                            NaN
# 18   stationary      brokenDownVehicle                            NaN
# 19          NaN                    NaN                       accident
# 20   stationary                    NaN                            NaN
# 21   stationary      brokenDownVehicle                            NaN
# 22          NaN                    NaN                       accident
# 23   stationary      brokenDownVehicle                            NaN
# 24   stationary      brokenDownVehicle                            NaN
# 25   stationary      brokenDownVehicle                            NaN
# 26   stationary      brokenDownVehicle                            NaN
# 27   stationary      brokenDownVehicle                            NaN
# 28   stationary      brokenDownVehicle                            NaN
# 29          NaN                    NaN                       accident
# 30   stationary      brokenDownVehicle                            NaN
# 31   stationary      brokenDownVehicle                            NaN
# 32          NaN                    NaN  accidentInvolvingHeavyLorries
# 33   stationary      brokenDownVehicle                            NaN
# 34   stationary      brokenDownVehicle                            NaN
# 35   stationary   brokenDownHeavyLorry                            NaN
# 36   stationary      brokenDownVehicle                            NaN
# 37   stationary   brokenDownHeavyLorry                            NaN
# 38          NaN                    NaN                       accident
# 39   stationary   brokenDownHeavyLorry                            NaN
# 40   stationary      brokenDownVehicle                            NaN
# 41   stationary      brokenDownVehicle                            NaN
# 42   stationary      brokenDownVehicle                            NaN
# 43          NaN                    NaN                       accident
# 44   stationary      brokenDownVehicle                            NaN
# 45          NaN                    NaN                       accident
# 46          NaN                    NaN                       accident
# 47   stationary      brokenDownVehicle                            NaN
#
#    alertcpoint pointbycoordinates
# 0          NaN                NaN
# 1          NaN                NaN
# 2          NaN                NaN
# 3          NaN                NaN
# 4          NaN                NaN
# 5          NaN                NaN
# 6          NaN                NaN
# 7          NaN                NaN
# 8          NaN                NaN
# 9          NaN                NaN
# 10         NaN                NaN
# 11         NaN                NaN
# 12         NaN                NaN
# 13         NaN                NaN
# 14         NaN                NaN
# 15         NaN                NaN
# 16           8           52.33728
# 17         NaN                NaN
# 18         NaN                NaN
# 19         NaN                NaN
# 20           8      52.2845125416
# 21         NaN                NaN
# 22           8         51.8681374
# 23         NaN                NaN
# 24           8         52.0573235
# 25         NaN                NaN
# 26           8         51.8746147
# 27         NaN                NaN
# 28         NaN                NaN
# 29         NaN                NaN
# 30         NaN                NaN
# 31         NaN                NaN
# 32         NaN                NaN
# 33           8           52.09242
# 34         NaN                NaN
# 35         NaN                NaN
# 36         NaN                NaN
# 37         NaN                NaN
# 38         NaN          52.570034
# 39         NaN                NaN
# 40         NaN                NaN
# 41         NaN                NaN
# 42         NaN                NaN
# 43           8         51.9802437
# 44         NaN                NaN
# 45           8         51.5264359
# 46         NaN                NaN
# 47         NaN                NaN

# %%
# Convert all values in dataframe into string instead of Navigable String for further processing

df = df.applymap(str)

# %%
df
# Out:
#     situation_id overallseverity  situationversiontime confidentiality  \
# 0   RWS03_956972         unknown  2020-12-17T15:33:15Z   noRestriction
# 1   RWS03_956973         unknown  2020-12-17T15:34:26Z   noRestriction
# 2   RWS03_956974         unknown  2020-12-17T15:36:05Z   noRestriction
# 3   RWS03_956975         unknown  2020-12-17T15:36:47Z   noRestriction
# 4   RWS03_956976         unknown  2020-12-17T15:40:18Z   noRestriction
# 5   RWS03_956977         unknown  2020-12-17T15:40:59Z   noRestriction
# 6   RWS03_956978         unknown  2020-12-17T15:44:50Z   noRestriction
# 7   RWS03_956979         unknown  2020-12-17T15:46:11Z   noRestriction
# 8   RWS03_956970         unknown  2020-12-17T15:30:24Z   noRestriction
# 9   RWS03_956971         unknown  2020-12-17T15:32:15Z   noRestriction
# 32         active  2020-12-17T15:19:05Z  53.2024241994  6.5522762678
# 33         active  2020-12-17T16:37:11Z       52.09242    5.17450857
# 34         active  2020-12-17T16:39:22Z       52.06467      4.805853
# 35         active  2020-12-17T16:39:53Z  52.2981607848  6.9665837292
# 36         active  2020-12-17T16:39:33Z       52.74441    6.81517935
# 37         active  2020-12-17T16:41:37Z  51.9403959772  5.0046939548
# 38         active  2020-12-17T16:40:49Z      52.570034    6.63314772
# 39         active  2020-12-17T16:11:07Z  52.3411749327  6.5947832974
# 40         active  2020-12-17T16:11:58Z       52.94539    6.53994656
# 41         active  2020-12-17T16:13:14Z       52.04755    4.35770226
# 42         active  2020-12-17T16:14:10Z     52.1601563      4.991612
# 43         active  2020-12-17T16:16:03Z     51.9802437      5.570764
# 44         active  2020-12-17T16:00:52Z       52.06614      4.779302
# 45         active  2020-12-17T15:57:31Z     51.5264359      5.390266
# 46         active  2020-12-17T16:01:43Z     51.8647842      4.544869
# 47         active  2020-12-17T16:08:50Z     51.9403954      5.004694
#
#    alertclocationcountrycode alertclocationtablenumber  \
# 0                          8                      5.21
# 1                          8                      5.21
# 2                          8                      5.21
# 3                          8                      5.21
# 4                          8                      5.21
# 5                          8                      5.21
# 6                          8                      5.21
# 7                          8                      5.21
# 8                          8                      5.21
# 9                          8                      5.21
# 10                         8                      5.21
# 11                         8                      5.21
# 12                         8                      5.21
# 13                         8                      5.21
# 14                         8                      5.21
# 15                         8                      5.21
# 16                         8                      5.21
# 17                         8                      5.21
# 18                         8                      5.21
# 19                         8                      5.21
# 20                         8                      5.21
# 21                         8                      5.21
# 22                         8                      5.21
# 23                         8                      5.21
# 24                         8                      5.21
# 25                         8                      5.21
# 26                         8                      5.21
# 27                         8                      5.21
# 28                         8                      5.21
# 29                         8                      5.21
# 30                         8                      5.21
# 31                         8                      5.21
# 32                         8                      5.21
# 33                         8                      5.21
# 34                         8                      5.21
# 35                         8                      5.21
# 36                         8                      5.21
# 37                         8                      5.21
# 38                       NaN                       NaN
# 39                         8                      5.21
# 40                         8                      5.21
# 41                         8                      5.21
# 42                         8                      5.21
# 43                         8                      5.21
# 44                         8                      5.21
# 45                         8                      5.21
# 46                         8                      5.21
# 47                         8                      5.21
#
#    alertclocationtableversion alertcdirectioncoded specificlocation  \
# 0                           A             negative            10589
# 1                           A             negative             7609
# 2                           A             positive             8353
# 3                           A             positive             8334
# 4                           A             negative             8862
# 5                           A             positive            10659
# 6                           A             negative             7263
# 7                           A             negative             8343
# 8                           A             positive             7284
# 9                           A             negative             9150
# 10                          A             positive             8513
# 11                          A             positive             8316
# 12                          A             positive             7627
# 13                          A             negative            22287
# 14                          A             negative             9155
# 15                          A             negative            22288
# 16                          A             negative             7004
# 17                          A             positive            10566
# 18                          A             negative            10019
# 19                          A             positive             8353
# 20                          A             negative            14189
# 21                          A             negative             9205
# 22                          A             positive             7433
# 23                          A             positive             8004
# 24                          A             positive             7293
# 25                          A             positive             7201
# 26                          A             negative             7448
# 27                          A             negative             7276
# 28                          A             negative             8099
# 29                          A             positive             7201
# 30                          A             positive             9647
# 31                          A             negative             7461
# 32                          A             negative            14970
# 33                          A             positive             8460
# 34                          A             negative             7276
# 35                          A             positive             7125
# 36                          A             negative            13929
# 37                          A             negative             8327
# 38                        NaN                  NaN              NaN
# 39                          A             negative             9026
# 40                          A             negative             8561
# 41                          A             positive             9202
# 42                          A             positive             7999
# 43                          A             positive            11498
# 44                          A             negative             7276
# 45                          A             negative             7934
# 46                          A             positive             7448
# 47                          A             negative             8327
#
#                             offsetdistance  \
# 0    <offsetdistance>1100</offsetdistance>
# 1   <offsetdistance>17600</offsetdistance>
# 2    <offsetdistance>3200</offsetdistance>
# 3    <offsetdistance>4800</offsetdistance>
# 4    <offsetdistance>2300</offsetdistance>
# 5    <offsetdistance>3800</offsetdistance>
# 6    <offsetdistance>2000</offsetdistance>
# 7    <offsetdistance>1500</offsetdistance>
# 8   <offsetdistance>49700</offsetdistance>
# 9    <offsetdistance>3900</offsetdistance>
# 10  <offsetdistance>34400</offsetdistance>
# 11   <offsetdistance>1600</offsetdistance>
# 12   <offsetdistance>2200</offsetdistance>
# 13   <offsetdistance>2100</offsetdistance>
# 14   <offsetdistance>1200</offsetdistance>
# 15    <offsetdistance>300</offsetdistance>
# 16    <offsetdistance>500</offsetdistance>
# 17   <offsetdistance>7100</offsetdistance>
# 18   <offsetdistance>1500</offsetdistance>
# 19   <offsetdistance>4000</offsetdistance>
# 20    <offsetdistance>100</offsetdistance>
# 21   <offsetdistance>2100</offsetdistance>
# 22    <offsetdistance>900</offsetdistance>
# 23  <offsetdistance>25600</offsetdistance>
# 24   <offsetdistance>1100</offsetdistance>
# 25   <offsetdistance>3200</offsetdistance>
# 26   <offsetdistance>1300</offsetdistance>
# 27   <offsetdistance>4000</offsetdistance>
# 28   <offsetdistance>2300</offsetdistance>
# 29   <offsetdistance>1300</offsetdistance>
# 30   <offsetdistance>5800</offsetdistance>
# 31   <offsetdistance>1800</offsetdistance>
# 32    <offsetdistance>200</offsetdistance>
# 33    <offsetdistance>300</offsetdistance>
# 34   <offsetdistance>4800</offsetdistance>
# 35   <offsetdistance>3800</offsetdistance>
# 36   <offsetdistance>3500</offsetdistance>
# 37   <offsetdistance>5400</offsetdistance>
# 38                                     nan
# 39   <offsetdistance>7900</offsetdistance>
# 40   <offsetdistance>6100</offsetdistance>
# 41   <offsetdistance>3100</offsetdistance>
# 42   <offsetdistance>2000</offsetdistance>
# 43      <offsetdistance>0</offsetdistance>
# 44   <offsetdistance>3000</offsetdistance>
# 45    <offsetdistance>600</offsetdistance>
# 46   <offsetdistance>2200</offsetdistance>
# 47   <offsetdistance>5400</offsetdistance>
#
#                   alertcmethod4secondarypointlocation safetyrelatedmessage  \
# 0   <alertclocation><specificlocation>10591</speci...                 true
# 1   <alertclocation><specificlocation>7623</specif...                 true
# 2   <alertclocation><specificlocation>8347</specif...                 true
# 3   <alertclocation><specificlocation>8330</specif...                 true
# 4   <alertclocation><specificlocation>8865</specif...                  NaN
# 5   <alertclocation><specificlocation>10665</speci...                 true
# 6   <alertclocation><specificlocation>7265</specif...                 true
# 7   <alertclocation><specificlocation>8347</specif...                 true
# 8   <alertclocation><specificlocation>7255</specif...                 true
# 9   <alertclocation><specificlocation>9154</specif...                 true
# 10  <alertclocation><specificlocation>8478</specif...                 true
# 11  <alertclocation><specificlocation>8315</specif...                 true
# 12  <alertclocation><specificlocation>7625</specif...                 true
# 13  <alertclocation><specificlocation>22288</speci...                 true
# 14  <alertclocation><specificlocation>9158</specif...                 true
# 15  <alertclocation><specificlocation>9190</specif...                 true
# 16                                                nan                 true
# 17  <alertclocation><specificlocation>10561</speci...                 true
# 18  <alertclocation><specificlocation>21883</speci...                 true
# 19  <alertclocation><specificlocation>8347</specif...                 true
# 20                                                nan                  NaN
# 21  <alertclocation><specificlocation>9208</specif...                 true
# 22                                                nan                 true
# 23  <alertclocation><specificlocation>7988</specif...                 true
# 24                                                nan                 true
# 25  <alertclocation><specificlocation>7193</specif...                 true
# 26                                                nan                 true
# 27  <alertclocation><specificlocation>7277</specif...                 true
# 28  <alertclocation><specificlocation>8101</specif...                 true
# 29  <alertclocation><specificlocation>7193</specif...                 true
# 30  <alertclocation><specificlocation>9643</specif...                 true
# 31  <alertclocation><specificlocation>7463</specif...                 true
# 32  <alertclocation><specificlocation>14971</speci...                  NaN
# 33                                                nan                 true
# 34  <alertclocation><specificlocation>7277</specif...                 true
# 35  <alertclocation><specificlocation>7119</specif...                 true
# 36  <alertclocation><specificlocation>13930</speci...                  NaN
# 37  <alertclocation><specificlocation>8330</specif...                 true
# 38                                                nan                  NaN
# 39  <alertclocation><specificlocation>9018</specif...                 true
# 40  <alertclocation><specificlocation>22264</speci...                 true
# 41  <alertclocation><specificlocation>9196</specif...                 true
# 42  <alertclocation><specificlocation>7996</specif...                 true
# 43                                                nan                  NaN
# 44  <alertclocation><specificlocation>7277</specif...                 true
# 45                                                nan                 true
# 46  <alertclocation><specificlocation>22528</speci...                 true
# 47  <alertclocation><specificlocation>8330</specif...                 true
#
#    mobilitytype vehicleobstructiontype                   accidenttype  \
# 0    stationary      brokenDownVehicle                            NaN
# 1    stationary      brokenDownVehicle                            NaN
# 2    stationary   brokenDownHeavyLorry                            NaN
# 3    stationary      brokenDownVehicle                            NaN
# 4    stationary      brokenDownVehicle                            NaN
# 5    stationary      brokenDownVehicle                            NaN
# 6    stationary      brokenDownVehicle                            NaN
# 7           NaN                    NaN                       accident
# 8    stationary      brokenDownVehicle                            NaN
# 9    stationary      brokenDownVehicle                            NaN
# 10   stationary      brokenDownVehicle                            NaN
# 11   stationary      brokenDownVehicle                            NaN
# 12   stationary      brokenDownVehicle                            NaN
# 13   stationary      brokenDownVehicle                            NaN
# 14          NaN                    NaN                       accident
# 15   stationary      brokenDownVehicle                            NaN
# 16   stationary      brokenDownVehicle                            NaN
# 17   stationary      brokenDownVehicle                            NaN
# 18   stationary      brokenDownVehicle                            NaN
# 19          NaN                    NaN                       accident
# 20   stationary                    NaN                            NaN
# 21   stationary      brokenDownVehicle                            NaN
# 22          NaN                    NaN                       accident
# 23   stationary      brokenDownVehicle                            NaN
# 24   stationary      brokenDownVehicle                            NaN
# 25   stationary      brokenDownVehicle                            NaN
# 26   stationary      brokenDownVehicle                            NaN
# 27   stationary      brokenDownVehicle                            NaN
# 28   stationary      brokenDownVehicle                            NaN
# 29          NaN                    NaN                       accident
# 30   stationary      brokenDownVehicle                            NaN
# 31   stationary      brokenDownVehicle                            NaN
# 32          NaN                    NaN  accidentInvolvingHeavyLorries
# 33   stationary      brokenDownVehicle                            NaN
# 34   stationary      brokenDownVehicle                            NaN
# 35   stationary   brokenDownHeavyLorry                            NaN
# 36   stationary      brokenDownVehicle                            NaN
# 37   stationary   brokenDownHeavyLorry                            NaN
# 38          NaN                    NaN                       accident
# 39   stationary   brokenDownHeavyLorry                            NaN
# 40   stationary      brokenDownVehicle                            NaN
# 41   stationary      brokenDownVehicle                            NaN
# 42   stationary      brokenDownVehicle                            NaN
# 43          NaN                    NaN                       accident
# 44   stationary      brokenDownVehicle                            NaN
# 45          NaN                    NaN                       accident
# 46          NaN                    NaN                       accident
# 47   stationary      brokenDownVehicle                            NaN
#
#                                           alertcpoint  \
# 0                                                 nan
# 1                                                 nan
# 2                                                 nan
# 3                                                 nan
# 4                                                 nan
# 5                                                 nan
# 6                                                 nan
# 7                                                 nan
# 8                                                 nan
# 9                                                 nan
# 10                                                nan
# 11                                                nan
# 12                                                nan
# 13                                                nan
# 14                                                nan
# 15                                                nan
# 16  <alertclocationcountrycode>8</alertclocationco...
# 17                                                nan
# 18                                                nan
# 19                                                nan
# 20  <alertclocationcountrycode>8</alertclocationco...
# 21                                                nan
# 22  <alertclocationcountrycode>8</alertclocationco...
# 23                                                nan
# 24  <alertclocationcountrycode>8</alertclocationco...
# 25                                                nan
# 26  <alertclocationcountrycode>8</alertclocationco...
# 27                                                nan
# 28                                                nan
# 29                                                nan
# 30                                                nan
# 31                                                nan
# 32                                                nan
# 33  <alertclocationcountrycode>8</alertclocationco...
# 34                                                nan
# 35                                                nan
# 36                                                nan
# 37                                                nan
# 38                                                nan
# 39                                                nan
# 40                                                nan
# 41                                                nan
# 42                                                nan
# 43  <alertclocationcountrycode>8</alertclocationco...
# 44                                                nan
# 45  <alertclocationcountrycode>8</alertclocationco...
# 46                                                nan
# 47                                                nan
#
#                                    pointbycoordinates
# 0                                                 nan
# 1                                                 nan
# 2                                                 nan
# 3                                                 nan
# 4                                                 nan
# 5                                                 nan
# 6                                                 nan
# 7                                                 nan
# 8                                                 nan
# 9                                                 nan
# 10                                                nan
# 11                                                nan
# 12                                                nan
# 13                                                nan
# 14                                                nan
# 15                                                nan
# 16  <pointcoordinates><latitude>52.33728</latitude...
# 17                                                nan
# 18                                                nan
# 19                                                nan
# 20  <pointcoordinates><latitude>52.2845125416</lat...
# 21                                                nan
# 22  <pointcoordinates><latitude>51.8681374</latitu...
# 23                                                nan
# 24  <pointcoordinates><latitude>52.0573235</latitu...
# 25                                                nan
# 26  <pointcoordinates><latitude>51.8746147</latitu...
# 27                                                nan
# 28                                                nan
# 29                                                nan
# 30                                                nan
# 31                                                nan
# 32                                                nan
# 33  <pointcoordinates><latitude>52.09242</latitude...
# 34                                                nan
# 35                                                nan
# 36                                                nan
# 37                                                nan
# 38  <pointcoordinates><latitude>52.570034</latitud...
# 39                                                nan
# 40                                                nan
# 41                                                nan
# 42                                                nan
# 43  <pointcoordinates><latitude>51.9802437</latitu...
# 44                                                nan
# 45  <pointcoordinates><latitude>51.5264359</latitu...
# 46                                                nan
# 47                                                nan

# %%
# List all columns containing date and time
time_columns = [str(i) for i in list(df.columns) if 'time' in i]

# Transform these columns into datetime format
df[time_columns] = pd.to_datetime(df[time_columns].stack()).unstack()

# %%
# List all columns containing only float numbers       
float_columns = []
for col in [col for col in df.columns if col not in time_columns]:
    if df[col].dropna().apply(lambda x: '.' in x).all():
        float_columns.append(col)
        
df[float_columns]
# Out:
#          latitude     longitude alertclocationtablenumber  \
# 0        52.42696      4.682106                      5.21
# 1      51.8396721    4.61365652                      5.21
# 2   52.0740886772  5.1545894393                      5.21
# 3        51.95544    5.05894756                      5.21
# 4        51.90743      5.872835                      5.21
# 5      52.1088066    4.69423771                      5.21
# 6        52.04667      4.496268                      5.21
# 7      52.0410347    5.14009047                      5.21
# 8       52.053936    4.39953566                      5.21
# 9      51.8964157      4.373382                      5.21
# 10       52.33029      5.614684                      5.21
# 11       51.78991      4.929431                      5.21
# 12     51.8907356    4.56171942                      5.21
# 13     51.9462166      4.356044                      5.21
# 14     51.9188576    4.36623335                      5.21
# 15     51.9535828       4.35061                      5.21
# 16       52.33728      4.989944                      5.21
# 17       52.33103    5.01723957                      5.21
# 18     51.3766365      5.332872                      5.21
# 19     52.0681534    5.14810133                      5.21
# 20  52.2845125416  6.5568907842                      5.21
# 21       52.08397      4.412724                      5.21
# 22     51.8681374    4.30089474                      5.21
# 23     52.0828056       5.07629                      5.21
# 24     52.0573235    5.14754963                      5.21
# 25       52.33771      4.891047                      5.21
# 26     51.8746147      4.570794                      5.21
# 27     52.0653343    4.79407549                      5.21
# 28       51.94707      4.511828                      5.21
# 29      52.339386    4.86166763                      5.21
# 30       51.52316      5.223938                      5.21
# 31       51.82894      4.765049                      5.21
# 32  53.2024241994  6.5522762678                      5.21
# 33       52.09242    5.17450857                      5.21
# 34       52.06467      4.805853                      5.21
# 35  52.2981607848  6.9665837292                      5.21
# 36       52.74441    6.81517935                      5.21
# 37  51.9403959772  5.0046939548                      5.21
# 38      52.570034    6.63314772                       NaN
# 39  52.3411749327  6.5947832974                      5.21
# 40       52.94539    6.53994656                      5.21
# 41       52.04755    4.35770226                      5.21
# 42     52.1601563      4.991612                      5.21
# 43     51.9802437      5.570764                      5.21
# 44       52.06614      4.779302                      5.21
# 45     51.5264359      5.390266                      5.21
# 46     51.8647842      4.544869                      5.21
# 47     51.9403954      5.004694                      5.21
#
#                                    pointbycoordinates
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16  <pointcoordinates><latitude>52.33728</latitude...
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20  <pointcoordinates><latitude>52.2845125416</lat...
# 21                                                NaN
# 22  <pointcoordinates><latitude>51.8681374</latitu...
# 23                                                NaN
# 24  <pointcoordinates><latitude>52.0573235</latitu...
# 25                                                NaN
# 26  <pointcoordinates><latitude>51.8746147</latitu...
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33  <pointcoordinates><latitude>52.09242</latitude...
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38  <pointcoordinates><latitude>52.570034</latitud...
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43  <pointcoordinates><latitude>51.9802437</latitu...
# 44                                                NaN
# 45  <pointcoordinates><latitude>51.5264359</latitu...
# 46                                                NaN
# 47                                                NaN

# %% [markdown]
# 1. Transform xml file into dataframe:
#     - amend data type where necessary
#     - build visualiztion on map
# 2. Compare files from different dates - what is the update process?
# 3. Find meaningful connections with other data
# 4. Set up pipeline
