# %%
import gzip
import xml.etree.ElementTree as ET


import requests
from bs4 import BeautifulSoup
import pandas as pd
import re

# %%
file = gzip.open('incidents.xml.gz', 'r')
tree = ET.parse(file)
root = tree.getroot()

print (root.tag)
print (root.attrib)
# Out:
# {http://schemas.xmlsoap.org/soap/envelope/}Envelope
# {}
# ...

# %%
for child in root:
    for a in child:
        print(a.tag, a.attrib)
# Out:
# {http://datex2.eu/schema/2/2_0}d2LogicalModel {'modelBaseVersion': '2'}

# %%
import gzip
from xml.dom.minidom import parse, parseString

# open and read gzipped xml file
infile = gzip.open('incidents.xml.gz')
content = infile.read()

# parse xml file content
dom = minidom.parseString(content)

# %%
print(content)
# Out:
# b'<?xml version="1.0" encoding="UTF-8"?><SOAP:Envelope xmlns:SOAP="http://schemas.xmlsoap.org/soap/envelope/"><SOAP:Body><d2LogicalModel xmlns="http://datex2.eu/schema/2/2_0" modelBaseVersion="2" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance"><exchange><supplierIdentification><country>nl</country><nationalIdentifier>NLNDW</nationalIdentifier></supplierIdentification><subscription><operatingMode>operatingMode3</operatingMode><subscriptionStartTime>2020-10-29T04:22:19.204Z</subscriptionStartTime><subscriptionState>active</subscriptionState><updateMethod>snapshot</updateMethod><target><address/><protocol>HTTP</protocol></target></subscription></exchange><payloadPublication xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:type="SituationPublication" lang="nl"><publicationTime>2020-12-17T16:44:50.449Z</publicationTime><publicationCreator><country>nl</country><nationalIdentifier>NLNDW</nationalIdentifier></publicationCreator><situation id="RWS03_956972" version="2"><overall
# ...

# %%
soup = BeautifulSoup(content, "lxml")

# %%
print(soup)
# Out:
# <?xml version="1.0" encoding="UTF-8"?><html><body><soap:envelope xmlns:soap="http://schemas.xmlsoap.org/soap/envelope/"><soap:body><d2logicalmodel modelbaseversion="2" xmlns="http://datex2.eu/schema/2/2_0" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance"><exchange><supplieridentification><country>nl</country><nationalidentifier>NLNDW</nationalidentifier></supplieridentification><subscription><operatingmode>operatingMode3</operatingmode><subscriptionstarttime>2020-10-29T04:22:19.204Z</subscriptionstarttime><subscriptionstate>active</subscriptionstate><updatemethod>snapshot</updatemethod><target><address></address><protocol>HTTP</protocol></target></subscription></exchange><payloadpublication lang="nl" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:type="SituationPublication"><publicationtime>2020-12-17T16:44:50.449Z</publicationtime><publicationcreator><country>nl</country><nationalidentifier>NLNDW</nationalidentifier></publicationcreator><situation id="RWS03_956972" v
# ...

# %%
cdict = {'class':'h3'}
repos = soup.find_all('h1', cdict)
repos
len(repos)

# %%
import xml.dom.minidom

# %%
# use the parse() function to load and parse an XML file
doc = xml.dom.minidom.parse("incidents.xml")

# %%
print (doc.firstChild.tagName)
# Out:
# SOAP:Envelope

# %%
a = doc.getElementsByTagName('situation')
# print(a)
for b in a:
    print(a.getAttribute('id'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-55-5ccad151e457> in <module>
#       2 # print(a)
#       3 for b in a:
# ----> 4     print(a.getAttribute('id'))
#
# AttributeError: 'NodeList' object has no attribute 'getAttribute'

# %%
for i in tree.iter():
    print(i)
# Out:
# <Element '{http://schemas.xmlsoap.org/soap/envelope/}Envelope' at 0x000002C8AD380680>
# <Element '{http://schemas.xmlsoap.org/soap/envelope/}Body' at 0x000002C8AD3582C0>
# <Element '{http://datex2.eu/schema/2/2_0}d2LogicalModel' at 0x000002C8AD358400>
# <Element '{http://datex2.eu/schema/2/2_0}exchange' at 0x000002C8AD3584A0>
# <Element '{http://datex2.eu/schema/2/2_0}supplierIdentification' at 0x000002C8AD3584F0>
# <Element '{http://datex2.eu/schema/2/2_0}country' at 0x000002C8AD358590>
# <Element '{http://datex2.eu/schema/2/2_0}nationalIdentifier' at 0x000002C8AD3585E0>
# <Element '{http://datex2.eu/schema/2/2_0}subscription' at 0x000002C8AD358680>
# <Element '{http://datex2.eu/schema/2/2_0}operatingMode' at 0x000002C8AD358720>
# <Element '{http://datex2.eu/schema/2/2_0}subscriptionStartTime' at 0x000002C8AD358770>
# <Element '{http://datex2.eu/schema/2/2_0}subscriptionState' at 0x000002C8AD358860>
# <Element '{http://datex2.eu/schema/2/2_0}updateMethod' at 0x000002C8AD358900>
# ...

# %%
tree.findall("{http://datex2.eu/schema/2/2_0}situation")
# Out:
# []
