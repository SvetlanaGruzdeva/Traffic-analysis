# %%
import gzip
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import requests
import re

# %%
pd.options.display.max_columns = 60

# %%
# open and read gzipped xml file
infile = gzip.open('incidents.xml.gz')
content = infile.read()

# Transform content into Beautiful Soup for further processing
soup = BeautifulSoup(content, "lxml")
soup
# Out:
# <?xml version="1.0" encoding="UTF-8"?><html><body><soap:envelope xmlns:soap="http://schemas.xmlsoap.org/soap/envelope/"><soap:body><d2logicalmodel modelbaseversion="2" xmlns="http://datex2.eu/schema/2/2_0" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance"><exchange><supplieridentification><country>nl</country><nationalidentifier>NLNDW</nationalidentifier></supplieridentification><subscription><operatingmode>operatingMode3</operatingmode><subscriptionstarttime>2020-10-29T04:22:19.204Z</subscriptionstarttime><subscriptionstate>active</subscriptionstate><updatemethod>snapshot</updatemethod><target><address></address><protocol>HTTP</protocol></target></subscription></exchange><payloadpublication lang="nl" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:type="SituationPublication"><publicationtime>2020-12-17T16:44:50.449Z</publicationtime><publicationcreator><country>nl</country><nationalidentifier>NLNDW</nationalidentifier></publicationcreator><situation id="RWS03_956972" version="2"><overallseverity>unknown</overallseverity><situationversiontime>2020-12-17T15:33:15Z</situationversiontime><headerinformation><confidentiality>noRestriction</confidentiality><informationstatus>real</informationstatus></headerinformation><situationrecord id="RWS03_956972_1" version="2" xsi:type="VehicleObstruction"><situationrecordcreationreference>LCM-LCM20168480_IM_1</situationrecordcreationreference><situationrecordcreationtime>2020-12-17T15:33:15Z</situationrecordcreationtime><situationrecordobservationtime>2020-12-17T15:33:15Z</situationrecordobservationtime><situationrecordversiontime>2020-12-17T15:33:15Z</situationrecordversiontime><situationrecordfirstsupplierversiontime>2020-12-17T15:33:15Z</situationrecordfirstsupplierversiontime><probabilityofoccurrence>certain</probabilityofoccurrence><source><sourcename><values><value lang="nl">VC Noordwest-Nederland</value></values></sourcename></source><validity><validitystatus>active</validitystatus><validitytimespecification><overallstarttime>2020-12-17T15:32:36Z</overallstarttime></validitytimespecification></validity><groupoflocations xsi:type="Linear"><locationfordisplay><latitude>52.42696</latitude><longitude>4.682106</longitude></locationfordisplay><alertclinear xsi:type="AlertCMethod4Linear"><alertclocationcountrycode>8</alertclocationcountrycode><alertclocationtablenumber>5.21</alertclocationtablenumber><alertclocationtableversion>A</alertclocationtableversion><alertcdirection><alertcdirectioncoded>negative</alertcdirectioncoded></alertcdirection><alertcmethod4primarypointlocation><alertclocation><specificlocation>10589</specificlocation></alertclocation><offsetdistance><offsetdistance>1100</offsetdistance></offsetdistance></alertcmethod4primarypointlocation><alertcmethod4secondarypointlocation><alertclocation><specificlocation>10591</specificlocation></alertclocation><offsetdistance><offsetdistance>2400</offsetdistance></offsetdistance></alertcmethod4secondarypointlocation></alertclinear><linearextension><linearbycoordinatesextension><linearcoordinatesstartpoint><pointcoordinates><latitude>52.42696</latitude><longitude>4.682106</longitude></pointcoordinates></linearcoordinatesstartpoint><linearcoordinatesendpoint><pointcoordinates><latitude>52.42696</latitude><longitude>4.682106</longitude></pointcoordinates></linearcoordinatesendpoint></linearbycoordinatesextension></linearextension></groupoflocations><situationrecordextension><situationrecordextendedapproved><safetyrelatedmessage>true</safetyrelatedmessage></situationrecordextendedapproved></situationrecordextension><mobilityofobstruction><mobilitytype>stationary</mobilitytype></mobilityofobstruction><vehicleobstructiontype>brokenDownVehicle</vehicleobstructiontype></situationrecord></situation><situation id="RWS03_956973" version="2"><overallseverity>unknown</overallseverity><situationversiontime>2020-12-17T15:34:26Z</situationversiontime><headerinformation><confidentiality>noRestriction</confidentiality><informationstatus>real ...

# %%
# cdict = {'id':'RWS03_956972'}
# repos = soup.find_all('situation', cdict)
# repos

# %%
# List all tags of the file

tags = [tag.name for tag in soup.find_all()]
tags
# Out:
# ['html',
#  'body',
#  'soap:envelope',
#  'soap:body',
#  'd2logicalmodel',
#  'exchange',
#  'supplieridentification',
#  'country',
#  'nationalidentifier',
#  'subscription',
#  'operatingmode',
#  'subscriptionstarttime',
#  'subscriptionstate',
#  'updatemethod',
#  'target',
#  'address',
#  'protocol',
#  'payloadpublication',
#  'publicationtime',
#  'publicationcreator',
#  'country',
#  'nationalidentifier',
#  'situation',
#  'overallseverity',
#  'situationversiontime',
#  'headerinformation',
#  'confidentiality',
#  'informationstatus',
#  'situationrecord',
#  'situationrecordcreationreference',
#  'situationrecordcreationtime',
#  'situationrecordobservationtime',
#  'situationrecordversiontime',
#  'situationrecordfirstsupplierversiontime',
#  'probabilityofoccurrence',
#  'source',
#  'sourcename',
#  'values',
#  'value',
#  'validity',
#  'validitystatus',
#  'validitytimespecification',
#  'overallstarttime',
#  'groupoflocations',
#  'locationfordisplay',
#  'latitude',
#  'longitude',
#  'alertclinear',
#  'alertclocationcountrycode',
#  'alertclocationtablenumber',
#  'alertclocationtableversion',
#  'alertcdirection',
#  'alertcdirectioncoded',
#  'alertcmethod4primarypointlocation',
#  'alertclocation',
#  'specificlocation',
#  'offsetdistance',
#  'offsetdistance',
#  'alertcmethod4secondarypointlocation',
#  'alertclocation',
#  'specificlocation',
#  'offsetdistance',
#  'offsetdistance',
#  'linearextension',
#  'linearbycoordinatesextension',
#  'linearcoordinatesstartpoint',
#  'pointcoordinates',
#  'latitude',
#  'longitude',
#  'linearcoordinatesendpoint',
#  'pointcoordinates',
#  'latitude',
#  'longitude',
#  'situationrecordextension',
#  'situationrecordextendedapproved',
#  'safetyrelatedmessage',
#  'mobilityofobstruction',
#  'mobilitytype',
#  'vehicleobstructiontype',
#  'situation',
#  'overallseverity',
#  'situationversiontime',
#  'headerinformation',
#  'confidentiality',
#  'informationstatus',
#  'situationrecord',
#  'situationrecordcreationreference',
#  'situationrecordcreationtime',
#  'situationrecordobservationtime',
#  'situationrecordversiontime',
#  'situationrecordfirstsupplierversiontime',
#  'probabilityofoccurrence',
#  'source',
#  'sourcename',
#  'values',
#  'value',
#  'validity',
#  'validitystatus',
#  'validitytimespecification',
#  'overallstarttime',
#  'groupoflocations',
#  'locationfordisplay',
#  'latitude',
#  'longitude',
#  'alertclinear',
#  'alertclocationcountrycode',
#  'alertclocationtablenumber',
#  'alertclocationtableversion',
#  'alertcdirection',
#  'alertcdirectioncoded',
#  'alertcmethod4primarypointlocation',
#  'alertclocation',
#  'specificlocation',
#  'offsetdistance',
#  'offsetdistance',
#  'alertcmethod4secondarypointlocation',
#  'alertclocation',
#  'specificlocation',
#  'offsetdistance',
#  'offsetdistance',
#  'linearextension',
#  'linearbycoordinatesextension',
#  'linearcoordinatesstartpoint',
#  'pointcoordinates',
#  'latitude',
#  'longitude',
#  'linearcoordinatesendpoint',
#  'pointcoordinates',
#  'latitude',
#  'longitude',
#  'situationrecordextension',
#  'situationrecordextendedapproved',
#  'safetyrelatedmessage',
#  'mobilityofobstruction',
#  'mobilitytype',
#  'vehicleobstructiontype',
#  'situation',
#  'overallseverity',
#  'situationversiontime',
#  'headerinformation',
#  'confidentiality',
#  'informationstatus',
#  'situationrecord',
#  'situationrecordcreationreference',
#  'situationrecordcreationtime',
#  'situationrecordobservationtime',
#  'situationrecordversiontime',
#  'situationrecordfirstsupplierversiontime',
#  'probabilityofoccurrence',
#  'source',
#  'sourcename',
#  'values',
#  'value',
#  'validity',
#  'validitystatus',
#  'validitytimespecification',
#  'overallstarttime',
#  'groupoflocations',
#  'locationfordisplay',
#  'latitude',
#  'longitude',
#  'alertclinear',
#  'alertclocationcountrycode',
#  'alertclocationtablenumber',
#  'alertclocationtableversion',
#  'alertcdirection',
#  'alertcdirectioncoded',
#  'alertcmethod4primarypointlocation',
#  'alertclocation',
#  'specificlocation',
#  'offsetdistance',
#  'offsetdistance',
#  'alertcmethod4secondarypointlocation',
#  'alertclocation',
#  'specificlocation',
#  'offsetdistance',
#  'offsetdistance',
#  'linearextension',
#  'linearbycoordinatesextension',
#  'linearcoordinatesstartpoint',
#  'pointcoordinates',
#  'latitude',
#  'longitude',
#  'linearcoordinatesendpoint',
#  'pointcoordinates',
#  'latitude',
#  'longitude',
#  'situationrecordextension',
#  'situationrecordextendedapproved',
#  'safetyrelatedmessage',
#  'mobilityofobstruction',
#  'mobilitytype',
#  'vehicleobstructiontype',
#  'situation',
#  'overallseverity',
#  'situationversiontime',
#  'headerinformation',
#  'confidentiality',
#  'informationstatus',
#  'situationrecord',
#  'situationrecordcreationreference',
#  'situationrecordcreationtime',
#  'situationrecordobservationtime',
#  'situationrecordversiontime',
#  'situationrecordfirstsupplierversiontime',
#  'probabilityofoccurrence',
#  'source',
#  'sourcename',
#  'values',
#  'value',
#  'validity',
#  'validitystatus',
#  'validitytimespecification',
#  'overallstarttime',
#  'groupoflocations',
#  'locationfordisplay',
#  'latitude',
#  'longitude',
#  'alertclinear',
#  'alertclocationcountrycode',
#  'alertclocationtablenumber',
#  'alertclocationtableversion',
#  'alertcdirection',
#  'alertcdirectioncoded',
#  'alertcmethod4primarypointlocation',
#  'alertclocation',
#  'specificlocation',
#  'offsetdistance',
#  'offsetdistance',
#  'alertcmethod4secondarypointlocation',
#  'alertclocation',
#  'specificlocation',
#  'offsetdistance',
#  'offsetdistance',
#  'linearextension',
#  'linearbycoordinatesextension',
#  'linearcoordinatesstartpoint',
#  'pointcoordinates',
#  'latitude',
#  'longitude',
#  'linearcoordinatesendpoint',
#  'pointcoordinates',
#  'latitude',
#  'longitude',
#  'situationrecordextension',
#  'situationrecordextendedapproved',
#  'safetyrelatedmessage',
#  'mobilityofobstruction',
#  'mobilitytype',
#  'vehicleobstructiontype',
#  'situation',
#  'overallseverity',
#  'situationversiontime',
#  'headerinformation',
#  'confidentiality',
#  'informationstatus',
#  'situationrecord',
#  'situationrecordcreationreference',
#  'situationrecordcreationtime',
#  'situationrecordobservationtime',
#  'situationrecordversiontime',
#  'situationrecordfirstsupplierversiontime',
#  'probabilityofoccurrence',
#  'source',
#  'sourcename',
#  'values',
#  'value',
#  'validity',
#  'validitystatus',
#  'validitytimespecification',
#  'overallstarttime',
#  'groupoflocations',
#  'locationfordisplay',
#  'latitude',
#  'longitude',
#  'alertclinear',
#  'alertclocationcountrycode',
#  'alertclocationtablenumber',
#  'alertclocationtableversion',
#  'alertcdirection',
#  'alertcdirectioncoded',
#  'alertcmethod4primarypointlocation',
#  'alertclocation',
#  'specificlocation',
#  'offsetdistance',
#  'offsetdistance',
#  'alertcmethod4secondarypointlocation',
#  'alertclocation',
#  'specificlocation',
#  'offsetdistance',
#  'offsetdistance',
#  'linearextension',
#  'linearbycoordinatesextension',
#  'linearcoordinatesstartpoint',
#  'pointcoordinates',
#  'latitude',
#  'longitude',
#  'linearcoordinatesendpoint',
#  'pointcoordinates',
#  'latitude',
#  'longitude',
#  'mobilityofobstruction',
#  'mobilitytype',
#  'vehicleobstructiontype',
#  'situation',
#  'overallseverity',
#  'situationversiontime',
#  'headerinformation',
#  'confidentiality',
#  'informationstatus',
#  'situationrecord',
#  'situationrecordcreationreference',
#  'situationrecordcreationtime',
#  'situationrecordobservationtime',
#  'situationrecordversiontime',
#  'situationrecordfirstsupplierversiontime',
#  'probabilityofoccurrence',
#  'source',
#  'sourcename',
#  'values',
#  'value',
#  'validity',
#  'validitystatus',
#  'validitytimespecification',
#  'overallstarttime',
#  'groupoflocations',
#  'locationfordisplay',
#  'latitude',
#  'longitude',
#  'alertclinear',
#  'alertclocationcountrycode',
#  'alertclocationtablenumber',
#  'alertclocationtableversion',
#  'alertcdirection',
#  'alertcdirectioncoded',
#  'alertcmethod4primarypointlocation',
#  'alertclocation',
#  'specificlocation',
#  'offsetdistance',
#  'offsetdistance',
#  'alertcmethod4secondarypointlocation',
#  'alertclocation',
#  'specificlocation',
#  'offsetdistance',
#  'offsetdistance',
#  'linearextension',
#  'linearbycoordinatesextension',
#  'linearcoordinatesstartpoint',
#  'pointcoordinates',
#  'latitude',
#  'longitude',
#  'linearcoordinatesendpoint',
#  'pointcoordinates',
#  'latitude',
#  'longitude',
#  'situationrecordextension',
#  'situationrecordextendedapproved',
#  'safetyrelatedmessage',
#  'mobilityofobstruction',
#  'mobilitytype',
#  'vehicleobstructiontype',
#  'situation',
#  'overallseverity',
#  'situationversiontime',
#  'headerinformation',
#  'confidentiality',
#  'informationstatus',
#  'situationrecord',
#  'situationrecordcreationreference',
#  'situationrecordcreationtime',
#  'situationrecordobservationtime',
#  'situationrecordversiontime',
#  'situationrecordfirstsupplierversiontime',
#  'probabilityofoccurrence',
#  'source',
#  'sourcename',
#  'values',
#  'value',
#  'validity',
#  'validitystatus',
#  'validitytimespecification',
#  'overallstarttime',
#  'groupoflocations',
#  'locationfordisplay',
#  'latitude',
#  'longitude',
#  'alertclinear',
#  'alertclocationcountrycode',
#  'alertclocationtablenumber',
#  'alertclocationtableversion',
#  'alertcdirection',
#  'alertcdirectioncoded',
#  'alertcmethod4primarypointlocation',
#  'alertclocation',
#  'specificlocation',
#  'offsetdistance',
#  'offsetdistance',
#  'alertcmethod4secondarypointlocation',
#  'alertclocation',
#  'specificlocation',
#  'offsetdistance',
#  'offsetdistance',
#  'linearextension',
#  'linearbycoordinatesextension',
#  'linearcoordinatesstartpoint',
#  'pointcoordinates',
#  'latitude',
#  'longitude',
#  'linearcoordinatesendpoint',
#  'pointcoordinates',
#  'latitude',
#  'longitude',
#  'situationrecordextension',
#  'situationrecordextendedapproved',
#  'safetyrelatedmessage',
#  'mobilityofobstruction',
#  'mobilitytype',
#  'vehicleobstructiontype',
#  'situation',
#  'overallseverity',
#  'situationversiontime',
#  'headerinformation',
#  'confidentiality',
#  'informationstatus',
#  'situationrecord',
#  'situationrecordcreationreference',
#  'situationrecordcreationtime',
#  'situationrecordobservationtime',
#  'situationrecordversiontime',
#  'situationrecordfirstsupplierversiontime',
#  'probabilityofoccurrence',
#  'source',
#  'sourcename',
#  'values',
#  'value',
#  'validity',
#  'validitystatus',
#  'validitytimespecification',
#  'overallstarttime',
#  'groupoflocations',
#  'locationfordisplay',
#  'latitude',
#  'longitude',
#  'alertclinear',
#  'alertclocationcountrycode',
#  'alertclocationtablenumber',
#  'alertclocationtableversion',
#  'alertcdirection',
#  'alertcdirectioncoded',
#  'alertcmethod4primarypointlocation',
#  'alertclocation',
#  'specificlocation',
#  'offsetdistance',
#  'offsetdistance',
#  'alertcmethod4secondarypointlocation',
#  'alertclocation',
#  'specificlocation',
#  'offsetdistance',
#  'offsetdistance',
#  'linearextension',
#  'linearbycoordinatesextension',
#  'linearcoordinatesstartpoint',
#  'pointcoordinates',
#  'latitude',
#  'longitude',
#  'linearcoordinatesendpoint',
#  'pointcoordinates',
#  'latitude',
#  'longitude',
#  'situationrecordextension',
#  'situationrecordextendedapproved',
#  'safetyrelatedmessage',
#  'accidenttype',
#  'situation',
#  'overallseverity',
#  'situationversiontime',
#  'headerinformation',
#  'confidentiality',
#  'informationstatus',
#  'situationrecord',
#  'situationrecordcreationreference',
#  'situationrecordcreationtime',
#  'situationrecordobservationtime',
#  'situationrecordversiontime',
#  'situationrecordfirstsupplierversiontime',
#  'probabilityofoccurrence',
#  'source',
#  'sourcename',
#  'values',
#  'value',
#  'validity',
#  'validitystatus',
#  'validitytimespecification',
#  'overallstarttime',
#  'groupoflocations',
#  'locationfordisplay',
#  'latitude',
#  'longitude',
#  'alertclinear',
#  'alertclocationcountrycode',
#  'alertclocationtablenumber',
#  'alertclocationtableversion',
#  'alertcdirection',
#  'alertcdirectioncoded',
#  'alertcmethod4primarypointlocation',
#  'alertclocation',
#  'specificlocation',
#  'offsetdistance',
#  'offsetdistance',
#  'alertcmethod4secondarypointlocation',
#  'alertclocation',
#  'specificlocation',
#  'offsetdistance',
#  'offsetdistance',
#  'linearextension',
#  'linearbycoordinatesextension',
#  'linearcoordinatesstartpoint',
#  'pointcoordinates',
#  'latitude',
#  'longitude',
#  'linearcoordinatesendpoint',
#  'pointcoordinates',
#  'latitude',
#  'longitude',
#  'situationrecordextension',
#  'situationrecordextendedapproved',
#  'safetyrelatedmessage',
#  'mobilityofobstruction',
#  'mobilitytype',
#  'vehicleobstructiontype',
#  'situation',
#  'overallseverity',
#  'situationversiontime',
#  'headerinformation',
#  'confidentiality',
#  'informationstatus',
#  'situationrecord',
#  'situationrecordcreationreference',
#  'situationrecordcreationtime',
#  'situationrecordobservationtime',
#  'situationrecordversiontime',
#  'situationrecordfirstsupplierversiontime',
#  'probabilityofoccurrence',
#  'source',
#  'sourcename',
#  'values',
#  'value',
#  'validity',
#  'validitystatus',
#  'validitytimespecification',
#  'overallstarttime',
#  'groupoflocations',
#  'locationfordisplay',
#  'latitude',
#  'longitude',
#  'alertclinear',
#  'alertclocationcountrycode',
#  'alertclocationtablenumber',
#  'alertclocationtableversion',
#  'alertcdirection',
#  'alertcdirectioncoded',
#  'alertcmethod4primarypointlocation',
#  'alertclocation',
#  'specificlocation',
#  'offsetdistance',
#  'offsetdistance',
#  'alertcmethod4secondarypointlocation',
#  'alertclocation',
#  'specificlocation',
#  'offsetdistance',
#  'offsetdistance',
#  'linearextension',
#  'linearbycoordinatesextension',
#  'linearcoordinatesstartpoint',
#  'pointcoordinates',
#  'latitude',
#  'longitude',
#  'linearcoordinatesendpoint',
#  'pointcoordinates',
#  'latitude',
#  'longitude',
#  'situationrecordextension',
#  'situationrecordextendedapproved',
#  'safetyrelatedmessage',
#  'mobilityofobstruction',
#  'mobilitytype',
#  'vehicleobstructiontype',
#  'situation',
#  'overallseverity',
#  'situationversiontime',
#  'headerinformation',
#  'confidentiality',
#  'informationstatus',
#  'situationrecord',
#  'situationrecordcreationreference',
#  'situationrecordcreationtime',
#  'situationrecordobservationtime',
#  'situationrecordversiontime',
#  'situationrecordfirstsupplierversiontime',
#  'probabilityofoccurrence',
#  'source',
#  'sourcename',
#  'values',
#  'value',
#  'validity',
#  'validitystatus',
#  'validitytimespecification',
#  'overallstarttime',
#  'groupoflocations',
#  'locationfordisplay',
#  'latitude',
#  'longitude',
#  'alertclinear',
#  'alertclocationcountrycode',
#  'alertclocationtablenumber',
#  'alertclocationtableversion',
#  'alertcdirection',
#  'alertcdirectioncoded',
#  'alertcmethod4primarypointlocation',
#  'alertclocation',
#  'specificlocation',
#  'offsetdistance',
#  'offsetdistance',
#  'alertcmethod4secondarypointlocation',
#  'alertclocation',
#  'specificlocation',
#  'offsetdistance',
#  'offsetdistance',
#  'linearextension',
#  'linearbycoordinatesextension',
#  'linearcoordinatesstartpoint',
#  'pointcoordinates',
#  'latitude',
#  'longitude',
#  'linearcoordinatesendpoint',
#  'pointcoordinates',
#  'latitude',
#  'longitude',
#  'situationrecordextension',
#  'situationrecordextendedapproved',
#  'safetyrelatedmessage',
#  'mobilityofobstruction',
#  'mobilitytype',
#  'vehicleobstructiontype',
#  'situation',
#  'overallseverity',
#  'situationversiontime',
#  'headerinformation',
#  'confidentiality',
#  'informationstatus',
#  'situationrecord',
#  'situationrecordcreationreference',
#  'situationrecordcreationtime',
#  'situationrecordobservationtime',
#  'situationrecordversiontime',
#  'situationrecordfirstsupplierversiontime',
#  'probabilityofoccurrence',
#  'source',
#  'sourcename',
#  'values',
#  'value',
#  'validity',
#  'validitystatus',
#  'validitytimespecification',
#  'overallstarttime',
#  'groupoflocations',
#  'locationfordisplay',
#  'latitude',
#  'longitude',
#  'alertclinear',
#  'alertclocationcountrycode',
#  'alertclocationtablenumber',
#  'alertclocationtableversion',
#  'alertcdirection',
#  'alertcdirectioncoded',
#  'alertcmethod4primarypointlocation',
#  'alertclocation',
#  'specificlocation',
#  'offsetdistance',
#  'offsetdistance',
#  'alertcmethod4secondarypointlocation',
#  'alertclocation',
#  'specificlocation',
#  'offsetdistance',
#  'offsetdistance',
#  'linearextension',
#  'linearbycoordinatesextension',
#  'linearcoordinatesstartpoint',
#  'pointcoordinates',
#  'latitude',
#  'longitude',
#  'linearcoordinatesendpoint',
#  'pointcoordinates',
#  'latitude',
#  'longitude',
#  'situationrecordextension',
#  'situationrecordextendedapproved',
#  'safetyrelatedmessage',
#  'mobilityofobstruction',
#  'mobilitytype',
#  'vehicleobstructiontype',
#  'situation',
#  'overallseverity',
#  'situationversiontime',
#  'headerinformation',
#  'confidentiality',
#  'informationstatus',
#  'situationrecord',
#  'situationrecordcreationreference',
#  'situationrecordcreationtime',
#  'situationrecordobservationtime',
#  'situationrecordversiontime',
#  'situationrecordfirstsupplierversiontime',
#  'probabilityofoccurrence',
#  'source',
#  'sourcename',
#  'values',
#  'value',
#  'validity',
#  'validitystatus',
#  'validitytimespecification',
#  'overallstarttime',
#  'groupoflocations',
#  'locationfordisplay',
#  'latitude',
#  'longitude',
#  'alertclinear',
#  'alertclocationcountrycode',
#  'alertclocationtablenumber',
#  'alertclocationtableversion',
#  'alertcdirection',
#  'alertcdirectioncoded',
#  'alertcmethod4primarypointlocation',
#  'alertclocation',
#  'specificlocation',
#  'offsetdistance',
#  'offsetdistance',
#  'alertcmethod4secondarypointlocation',
#  'alertclocation',
#  'specificlocation',
#  'offsetdistance',
#  'offsetdistance',
#  'linearextension',
#  'linearbycoordinatesextension',
#  'linearcoordinatesstartpoint',
#  'pointcoordinates',
#  'latitude',
#  'longitude',
#  'linearcoordinatesendpoint',
#  'pointcoordinates',
#  'latitude',
#  'longitude',
#  'situationrecordextension',
#  'situationrecordextendedapproved',
#  'safetyrelatedmessage',
#  'mobilityofobstruction',
#  'mobilitytype',
#  'vehicleobstructiontype',
#  'situation',
#  'overallseverity',
#  'situationversiontime',
#  'headerinformation',
#  'confidentiality',
#  'informationstatus',
#  'situationrecord',
#  'situationrecordcreationreference',
#  'situationrecordcreationtime',
#  'situationrecordobservationtime',
#  'situationrecordversiontime',
#  'situationrecordfirstsupplierversiontime',
#  'probabilityofoccurrence',
#  'source',
#  'sourcename',
#  'values',
#  'value',
#  'validity',
#  'validitystatus',
#  'validitytimespecification',
#  'overallstarttime',
#  'groupoflocations',
#  'locationfordisplay',
#  'latitude',
#  'longitude',
#  'alertclinear',
#  'alertclocationcountrycode',
#  'alertclocationtablenumber',
#  'alertclocationtableversion',
#  'alertcdirection',
#  'alertcdirectioncoded',
#  'alertcmethod4primarypointlocation',
#  'alertclocation',
#  'specificlocation',
#  'offsetdistance',
#  'offsetdistance',
#  'alertcmethod4secondarypointlocation',
#  'alertclocation',
#  'specificlocation',
#  'offsetdistance',
#  'offsetdistance',
#  'linearextension',
#  'linearbycoordinatesextension',
#  'linearcoordinatesstartpoint',
#  'pointcoordinates',
#  'latitude',
#  'longitude',
#  'linearcoordinatesendpoint',
#  'pointcoordinates',
#  'latitude',
#  'longitude',
#  'situationrecordextension',
#  'situationrecordextendedapproved',
#  'safetyrelatedmessage',
#  'mobilityofobstruction',
#  'mobilitytype',
#  'vehicleobstructiontype',
#  'situation',
#  'overallseverity',
#  'situationversiontime',
#  'headerinformation',
#  'confidentiality',
#  'informationstatus',
#  'situationrecord',
#  'situationrecordcreationreference',
#  'situationrecordcreationtime',
#  'situationrecordobservationtime',
#  'situationrecordversiontime',
#  'situationrecordfirstsupplierversiontime',
#  'probabilityofoccurrence',
#  'source',
#  'sourcename',
#  'values',
#  'value',
#  'validity',
#  'validitystatus',
#  'validitytimespecification',
#  'overallstarttime',
#  'groupoflocations',
#  'locationfordisplay',
#  'latitude',
#  'longitude',
#  'alertclinear',
#  'alertclocationcountrycode',
#  'alertclocationtablenumber',
#  'alertclocationtableversion',
#  'alertcdirection',
#  'alertcdirectioncoded',
#  'alertcmethod4primarypointlocation',
#  'alertclocation',
#  'specificlocation',
#  'offsetdistance',
#  'offsetdistance',
#  'alertcmethod4secondarypointlocation',
#  'alertclocation',
#  'specificlocation',
#  'offsetdistance',
#  'offsetdistance',
#  'linearextension',
#  'linearbycoordinatesextension',
#  'linearcoordinatesstartpoint',
#  'pointcoordinates',
#  'latitude',
#  'longitude',
#  'linearcoordinatesendpoint',
#  'pointcoordinates',
#  'latitude',
#  'longitude',
#  'situationrecordextension',
#  'situationrecordextendedapproved',
#  'safetyrelatedmessage',
#  'accidenttype',
#  'situation',
#  'overallseverity',
#  'situationversiontime',
#  'headerinformation',
#  'confidentiality',
#  'informationstatus',
#  'situationrecord',
#  'situationrecordcreationreference',
#  'situationrecordcreationtime',
#  'situationrecordobservationtime',
#  'situationrecordversiontime',
#  'situationrecordfirstsupplierversiontime',
#  'probabilityofoccurrence',
#  'source',
#  'sourcename',
#  'values',
#  'value',
#  'validity',
#  'validitystatus',
#  'validitytimespecification',
#  'overallstarttime',
#  'groupoflocations',
#  'locationfordisplay',
#  'latitude',
#  'longitude',
#  'alertclinear',
#  'alertclocationcountrycode',
#  'alertclocationtablenumber',
#  'alertclocationtableversion',
#  'alertcdirection',
#  'alertcdirectioncoded',
#  'alertcmethod4primarypointlocation',
#  'alertclocation',
#  'specificlocation',
#  'offsetdistance',
#  'offsetdistance',
#  'alertcmethod4secondarypointlocation',
#  'alertclocation',
#  'specificlocation',
#  'offsetdistance',
#  'offsetdistance',
#  'linearextension',
#  'linearbycoordinatesextension',
#  'linearcoordinatesstartpoint',
#  'pointcoordinates',
#  'latitude',
#  'longitude',
#  'linearcoordinatesendpoint',
#  'pointcoordinates',
#  'latitude',
#  'longitude',
#  'situationrecordextension',
#  'situationrecordextendedapproved',
#  'safetyrelatedmessage',
#  'mobilityofobstruction',
#  'mobilitytype',
#  'vehicleobstructiontype',
#  'situation',
#  'overallseverity',
#  'situationversiontime',
#  'headerinformation',
#  'confidentiality',
#  'informationstatus',
#  'situationrecord',
#  'situationrecordcreationreference',
#  'situationrecordcreationtime',
#  'situationrecordobservationtime',
#  'situationrecordversiontime',
#  'situationrecordfirstsupplierversiontime',
#  'probabilityofoccurrence',
#  'source',
#  'sourcename',
#  'values',
#  'value',
#  'validity',
#  'validitystatus',
#  'validitytimespecification',
#  'overallstarttime',
#  'groupoflocations',
#  'locationfordisplay',
#  'latitude',
#  'longitude',
#  'alertcpoint',
#  'alertclocationcountrycode',
#  'alertclocationtablenumber',
#  'alertclocationtableversion',
#  'alertcdirection',
#  'alertcdirectioncoded',
#  'alertcmethod4primarypointlocation',
#  'alertclocation',
#  'specificlocation',
#  'offsetdistance',
#  'offsetdistance',
#  'pointbycoordinates',
#  'pointcoordinates',
#  'latitude',
#  'longitude',
#  'situationrecordextension',
#  'situationrecordextendedapproved',
#  'safetyrelatedmessage',
#  'mobilityofobstruction',
#  'mobilitytype',
#  'vehicleobstructiontype',
#  'situation',
#  'overallseverity',
#  'situationversiontime',
#  'headerinformation',
#  'confidentiality',
#  'informationstatus',
#  'situationrecord',
#  'situationrecordcreationreference',
#  'situationrecordcreationtime',
#  'situationrecordobservationtime',
#  'situationrecordversiontime',
#  'situationrecordfirstsupplierversiontime',
#  'probabilityofoccurrence',
#  'source',
#  'sourcename',
#  'values',
#  'value',
#  'validity',
#  'validitystatus',
#  'validitytimespecification',
#  'overallstarttime',
#  'groupoflocations',
#  'locationfordisplay',
#  'latitude',
#  'longitude',
#  'alertclinear',
#  'alertclocationcountrycode',
#  ...]

# %%
# Work-around to find content of 'situation' tag

indices = [i for i, x in enumerate(tags) if x == "situation"]
print(indices)
for i in range(len(indices)-1):
    print(indices[i+1]-indices[i])
# Out:
# [22, 79, 136, 193, 250, 304, 361, 418, 473, 530, 587, 644, 701, 758, 815, 870, 927, 973, 1030, 1087, 1142, 1185, 1242, 1286, 1343, 1389, 1446, 1492, 1549, 1606, 1661, 1718, 1775, 1827, 1873, 1930, 1987, 2041, 2098, 2138, 2195, 2252, 2309, 2366, 2407, 2464, 2508, 2563]
# 57
# 57
# 57
# 57
# 54
# 57
# 57
# 55
# 57
# 57
# 57
# 57
# 57
# 57
# 55
# 57
# 46
# 57
# 57
# 55
# 43
# 57
# 44
# 57
# 46
# 57
# 46
# 57
# 57
# 55
# 57
# 57
# 52
# 46
# 57
# 57
# 54
# 57
# 40
# 57
# 57
# 57
# 57
# 41
# 57
# 44
# 55

# %%
# There are 48 situations with different number of tags within each. The first situation starts from tag 22.

situation_tags = set(tags[22:])
situation_tags
# Out:
# {'accidenttype',
#  'administrativearea',
#  'alertcdirection',
#  'alertcdirectioncoded',
#  'alertclinear',
#  'alertclocation',
#  'alertclocationcountrycode',
#  'alertclocationtablenumber',
#  'alertclocationtableversion',
#  'alertcmethod4primarypointlocation',
#  'alertcmethod4secondarypointlocation',
#  'alertcpoint',
#  'confidentiality',
#  'groupoflocations',
#  'headerinformation',
#  'informationstatus',
#  'latitude',
#  'linearbycoordinatesextension',
#  'linearcoordinatesendpoint',
#  'linearcoordinatesstartpoint',
#  'linearextension',
#  'locationfordisplay',
#  'longitude',
#  'mobilityofobstruction',
#  'mobilitytype',
#  'obstructiontype',
#  'offsetdistance',
#  'overallseverity',
#  'overallstarttime',
#  'pointbycoordinates',
#  'pointcoordinates',
#  'pointextension',
#  'probabilityofoccurrence',
#  'roadname',
#  'roadsidereferencepoint',
#  'roadsidereferencepointidentifier',
#  'safetyrelatedmessage',
#  'situation',
#  'situationrecord',
#  'situationrecordcreationreference',
#  'situationrecordcreationtime',
#  'situationrecordextendedapproved',
#  'situationrecordextension',
#  'situationrecordfirstsupplierversiontime',
#  'situationrecordobservationtime',
#  'situationrecordversiontime',
#  'situationversiontime',
#  'source',
#  'sourcename',
#  'specificlocation',
#  'validity',
#  'validitystatus',
#  'validitytimespecification',
#  'value',
#  'values',
#  'vehicleobstructiontype'}

# %%
# Ids of each situation in the file

ids = [tag['id'] for tag in soup.select('situation[id]')]
ids
# Out:
# ['RWS03_956972',
#  'RWS03_956973',
#  'RWS03_956974',
#  'RWS03_956975',
#  'RWS03_956976',
#  'RWS03_956977',
#  'RWS03_956978',
#  'RWS03_956979',
#  'RWS03_956970',
#  'RWS03_956971',
#  'RWS03_956983',
#  'RWS03_956984',
#  'RWS03_956985',
#  'RWS03_956986',
#  'RWS03_956987',
#  'RWS03_956988',
#  'RWS03_956989',
#  'RWS03_956980',
#  'RWS03_956981',
#  'RWS03_956982',
#  'RWS03_956554',
#  'RWS03_957005',
#  'RWS03_957006',
#  'RWS03_957007',
#  'RWS03_957008',
#  'RWS03_957009',
#  'RWS03_957000',
#  'RWS03_957001',
#  'RWS03_957002',
#  'RWS03_957003',
#  'RWS03_957004',
#  'RWS03_957017',
#  'RWS03_956967',
#  'RWS03_957010',
#  'RWS03_957011',
#  'RWS03_957012',
#  'RWS03_957013',
#  'RWS03_957014',
#  'RWS03_957015',
#  'RWS03_956994',
#  'RWS03_956995',
#  'RWS03_956996',
#  'RWS03_956997',
#  'RWS03_956999',
#  'RWS03_956990',
#  'RWS03_956991',
#  'RWS03_956992',
#  'RWS03_956993']

# %%
cdict = {'id':'RWS03_956972'}
situation = soup.find_all('situation', cdict)
childs = [tag.name for tag in situation[0].find_all()]
childs
# Out:
# ['overallseverity',
#  'situationversiontime',
#  'headerinformation',
#  'confidentiality',
#  'informationstatus',
#  'situationrecord',
#  'situationrecordcreationreference',
#  'situationrecordcreationtime',
#  'situationrecordobservationtime',
#  'situationrecordversiontime',
#  'situationrecordfirstsupplierversiontime',
#  'probabilityofoccurrence',
#  'source',
#  'sourcename',
#  'values',
#  'value',
#  'validity',
#  'validitystatus',
#  'validitytimespecification',
#  'overallstarttime',
#  'groupoflocations',
#  'locationfordisplay',
#  'latitude',
#  'longitude',
#  'alertclinear',
#  'alertclocationcountrycode',
#  'alertclocationtablenumber',
#  'alertclocationtableversion',
#  'alertcdirection',
#  'alertcdirectioncoded',
#  'alertcmethod4primarypointlocation',
#  'alertclocation',
#  'specificlocation',
#  'offsetdistance',
#  'offsetdistance',
#  'alertcmethod4secondarypointlocation',
#  'alertclocation',
#  'specificlocation',
#  'offsetdistance',
#  'offsetdistance',
#  'linearextension',
#  'linearbycoordinatesextension',
#  'linearcoordinatesstartpoint',
#  'pointcoordinates',
#  'latitude',
#  'longitude',
#  'linearcoordinatesendpoint',
#  'pointcoordinates',
#  'latitude',
#  'longitude',
#  'situationrecordextension',
#  'situationrecordextendedapproved',
#  'safetyrelatedmessage',
#  'mobilityofobstruction',
#  'mobilitytype',
#  'vehicleobstructiontype']

# %%
# Present each situation as a separate dataframe and collect all dataframes in a list

df_list = []
for id_code in ids:
    situation_dict = {'situation_id':id_code}

    for tag in childs:
        situation_dict[tag] = situation[0].find_all(tag)[0].next
    
    df_list.append(pd.DataFrame.from_dict(situation_dict, orient='index'))

# %%
# Aggreage all situations in one dataframe

df = pd.concat(df_list, axis=1).transpose().reset_index().drop('index', axis=1)

# %%
# Drop duplicated columns

to_drop = ['headerinformation','situationrecord','source', 'sourcename', 'values', 'validity', 'validitytimespecification',
          'groupoflocations', 'locationfordisplay', 'alertclinear', 'alertcdirection', 'alertcmethod4primarypointlocation',
          'alertclocation', 'linearextension', 'linearbycoordinatesextension', 'situationrecordextension',
          'situationrecordextendedapproved', 'mobilityofobstruction']
df.drop(to_drop, axis=1, inplace=True)

# %%
df
# Out:
#     situation_id overallseverity  situationversiontime confidentiality  \
# 0   RWS03_956972         unknown  2020-12-17T15:33:15Z   noRestriction
# 1   RWS03_956973         unknown  2020-12-17T15:33:15Z   noRestriction
# 2   RWS03_956974         unknown  2020-12-17T15:33:15Z   noRestriction
# 3   RWS03_956975         unknown  2020-12-17T15:33:15Z   noRestriction
# 4   RWS03_956976         unknown  2020-12-17T15:33:15Z   noRestriction
# 5   RWS03_956977         unknown  2020-12-17T15:33:15Z   noRestriction
# 6   RWS03_956978         unknown  2020-12-17T15:33:15Z   noRestriction
# 7   RWS03_956979         unknown  2020-12-17T15:33:15Z   noRestriction
# 8   RWS03_956970         unknown  2020-12-17T15:33:15Z   noRestriction
# 9   RWS03_956971         unknown  2020-12-17T15:33:15Z   noRestriction
# 10  RWS03_956983         unknown  2020-12-17T15:33:15Z   noRestriction
# 11  RWS03_956984         unknown  2020-12-17T15:33:15Z   noRestriction
# 12  RWS03_956985         unknown  2020-12-17T15:33:15Z   noRestriction
# 13  RWS03_956986         unknown  2020-12-17T15:33:15Z   noRestriction
# 14  RWS03_956987         unknown  2020-12-17T15:33:15Z   noRestriction
# 15  RWS03_956988         unknown  2020-12-17T15:33:15Z   noRestriction
# 16  RWS03_956989         unknown  2020-12-17T15:33:15Z   noRestriction
# 17  RWS03_956980         unknown  2020-12-17T15:33:15Z   noRestriction
# 18  RWS03_956981         unknown  2020-12-17T15:33:15Z   noRestriction
# 19  RWS03_956982         unknown  2020-12-17T15:33:15Z   noRestriction
# 20  RWS03_956554         unknown  2020-12-17T15:33:15Z   noRestriction
# 21  RWS03_957005         unknown  2020-12-17T15:33:15Z   noRestriction
# 22  RWS03_957006         unknown  2020-12-17T15:33:15Z   noRestriction
# 23  RWS03_957007         unknown  2020-12-17T15:33:15Z   noRestriction
# 24  RWS03_957008         unknown  2020-12-17T15:33:15Z   noRestriction
# 25  RWS03_957009         unknown  2020-12-17T15:33:15Z   noRestriction
# 26  RWS03_957000         unknown  2020-12-17T15:33:15Z   noRestriction
# 27  RWS03_957001         unknown  2020-12-17T15:33:15Z   noRestriction
# 28  RWS03_957002         unknown  2020-12-17T15:33:15Z   noRestriction
# 29  RWS03_957003         unknown  2020-12-17T15:33:15Z   noRestriction
# 30  RWS03_957004         unknown  2020-12-17T15:33:15Z   noRestriction
# 31  RWS03_957017         unknown  2020-12-17T15:33:15Z   noRestriction
# 32  RWS03_956967         unknown  2020-12-17T15:33:15Z   noRestriction
# 33  RWS03_957010         unknown  2020-12-17T15:33:15Z   noRestriction
# 34  RWS03_957011         unknown  2020-12-17T15:33:15Z   noRestriction
# 35  RWS03_957012         unknown  2020-12-17T15:33:15Z   noRestriction
# 36  RWS03_957013         unknown  2020-12-17T15:33:15Z   noRestriction
# 37  RWS03_957014         unknown  2020-12-17T15:33:15Z   noRestriction
# 38  RWS03_957015         unknown  2020-12-17T15:33:15Z   noRestriction
# 39  RWS03_956994         unknown  2020-12-17T15:33:15Z   noRestriction
# 40  RWS03_956995         unknown  2020-12-17T15:33:15Z   noRestriction
# 41  RWS03_956996         unknown  2020-12-17T15:33:15Z   noRestriction
# 42  RWS03_956997         unknown  2020-12-17T15:33:15Z   noRestriction
# 43  RWS03_956999         unknown  2020-12-17T15:33:15Z   noRestriction
# 44  RWS03_956990         unknown  2020-12-17T15:33:15Z   noRestriction
# 45  RWS03_956991         unknown  2020-12-17T15:33:15Z   noRestriction
# 46  RWS03_956992         unknown  2020-12-17T15:33:15Z   noRestriction
# 47  RWS03_956993         unknown  2020-12-17T15:33:15Z   noRestriction
#
#    informationstatus situationrecordcreationreference  \
# 0               real             LCM-LCM20168480_IM_1
# 1               real             LCM-LCM20168480_IM_1
# 2               real             LCM-LCM20168480_IM_1
# 3               real             LCM-LCM20168480_IM_1
# 4               real             LCM-LCM20168480_IM_1
# 5               real             LCM-LCM20168480_IM_1
# 6               real             LCM-LCM20168480_IM_1
# 7               real             LCM-LCM20168480_IM_1
# 8               real             LCM-LCM20168480_IM_1
# 9               real             LCM-LCM20168480_IM_1
# 10              real             LCM-LCM20168480_IM_1
# 11              real             LCM-LCM20168480_IM_1
# 12              real             LCM-LCM20168480_IM_1
# 13              real             LCM-LCM20168480_IM_1
# 14              real             LCM-LCM20168480_IM_1
# 15              real             LCM-LCM20168480_IM_1
# 16              real             LCM-LCM20168480_IM_1
# 17              real             LCM-LCM20168480_IM_1
# 18              real             LCM-LCM20168480_IM_1
# 19              real             LCM-LCM20168480_IM_1
# 20              real             LCM-LCM20168480_IM_1
# 21              real             LCM-LCM20168480_IM_1
# 22              real             LCM-LCM20168480_IM_1
# 23              real             LCM-LCM20168480_IM_1
# 24              real             LCM-LCM20168480_IM_1
# 25              real             LCM-LCM20168480_IM_1
# 26              real             LCM-LCM20168480_IM_1
# 27              real             LCM-LCM20168480_IM_1
# 28              real             LCM-LCM20168480_IM_1
# 29              real             LCM-LCM20168480_IM_1
# 30              real             LCM-LCM20168480_IM_1
# 31              real             LCM-LCM20168480_IM_1
# 32              real             LCM-LCM20168480_IM_1
# 33              real             LCM-LCM20168480_IM_1
# 34              real             LCM-LCM20168480_IM_1
# 35              real             LCM-LCM20168480_IM_1
# 36              real             LCM-LCM20168480_IM_1
# 37              real             LCM-LCM20168480_IM_1
# 38              real             LCM-LCM20168480_IM_1
# 39              real             LCM-LCM20168480_IM_1
# 40              real             LCM-LCM20168480_IM_1
# 41              real             LCM-LCM20168480_IM_1
# 42              real             LCM-LCM20168480_IM_1
# 43              real             LCM-LCM20168480_IM_1
# 44              real             LCM-LCM20168480_IM_1
# 45              real             LCM-LCM20168480_IM_1
# 46              real             LCM-LCM20168480_IM_1
# 47              real             LCM-LCM20168480_IM_1
#
#    situationrecordcreationtime situationrecordobservationtime  \
# 0         2020-12-17T15:33:15Z           2020-12-17T15:33:15Z
# 1         2020-12-17T15:33:15Z           2020-12-17T15:33:15Z
# 2         2020-12-17T15:33:15Z           2020-12-17T15:33:15Z
# 3         2020-12-17T15:33:15Z           2020-12-17T15:33:15Z
# 4         2020-12-17T15:33:15Z           2020-12-17T15:33:15Z
# 5         2020-12-17T15:33:15Z           2020-12-17T15:33:15Z
# 6         2020-12-17T15:33:15Z           2020-12-17T15:33:15Z
# 7         2020-12-17T15:33:15Z           2020-12-17T15:33:15Z
# 8         2020-12-17T15:33:15Z           2020-12-17T15:33:15Z
# 9         2020-12-17T15:33:15Z           2020-12-17T15:33:15Z
# 10        2020-12-17T15:33:15Z           2020-12-17T15:33:15Z
# 11        2020-12-17T15:33:15Z           2020-12-17T15:33:15Z
# 12        2020-12-17T15:33:15Z           2020-12-17T15:33:15Z
# 13        2020-12-17T15:33:15Z           2020-12-17T15:33:15Z
# 14        2020-12-17T15:33:15Z           2020-12-17T15:33:15Z
# 15        2020-12-17T15:33:15Z           2020-12-17T15:33:15Z
# 16        2020-12-17T15:33:15Z           2020-12-17T15:33:15Z
# 17        2020-12-17T15:33:15Z           2020-12-17T15:33:15Z
# 18        2020-12-17T15:33:15Z           2020-12-17T15:33:15Z
# 19        2020-12-17T15:33:15Z           2020-12-17T15:33:15Z
# 20        2020-12-17T15:33:15Z           2020-12-17T15:33:15Z
# 21        2020-12-17T15:33:15Z           2020-12-17T15:33:15Z
# 22        2020-12-17T15:33:15Z           2020-12-17T15:33:15Z
# 23        2020-12-17T15:33:15Z           2020-12-17T15:33:15Z
# 24        2020-12-17T15:33:15Z           2020-12-17T15:33:15Z
# 25        2020-12-17T15:33:15Z           2020-12-17T15:33:15Z
# 26        2020-12-17T15:33:15Z           2020-12-17T15:33:15Z
# 27        2020-12-17T15:33:15Z           2020-12-17T15:33:15Z
# 28        2020-12-17T15:33:15Z           2020-12-17T15:33:15Z
# 29        2020-12-17T15:33:15Z           2020-12-17T15:33:15Z
# 30        2020-12-17T15:33:15Z           2020-12-17T15:33:15Z
# 31        2020-12-17T15:33:15Z           2020-12-17T15:33:15Z
# 32        2020-12-17T15:33:15Z           2020-12-17T15:33:15Z
# 33        2020-12-17T15:33:15Z           2020-12-17T15:33:15Z
# 34        2020-12-17T15:33:15Z           2020-12-17T15:33:15Z
# 35        2020-12-17T15:33:15Z           2020-12-17T15:33:15Z
# 36        2020-12-17T15:33:15Z           2020-12-17T15:33:15Z
# 37        2020-12-17T15:33:15Z           2020-12-17T15:33:15Z
# 38        2020-12-17T15:33:15Z           2020-12-17T15:33:15Z
# 39        2020-12-17T15:33:15Z           2020-12-17T15:33:15Z
# 40        2020-12-17T15:33:15Z           2020-12-17T15:33:15Z
# 41        2020-12-17T15:33:15Z           2020-12-17T15:33:15Z
# 42        2020-12-17T15:33:15Z           2020-12-17T15:33:15Z
# 43        2020-12-17T15:33:15Z           2020-12-17T15:33:15Z
# 44        2020-12-17T15:33:15Z           2020-12-17T15:33:15Z
# 45        2020-12-17T15:33:15Z           2020-12-17T15:33:15Z
# 46        2020-12-17T15:33:15Z           2020-12-17T15:33:15Z
# 47        2020-12-17T15:33:15Z           2020-12-17T15:33:15Z
#
#    situationrecordversiontime situationrecordfirstsupplierversiontime  \
# 0        2020-12-17T15:33:15Z                    2020-12-17T15:33:15Z
# 1        2020-12-17T15:33:15Z                    2020-12-17T15:33:15Z
# 2        2020-12-17T15:33:15Z                    2020-12-17T15:33:15Z
# 3        2020-12-17T15:33:15Z                    2020-12-17T15:33:15Z
# 4        2020-12-17T15:33:15Z                    2020-12-17T15:33:15Z
# 5        2020-12-17T15:33:15Z                    2020-12-17T15:33:15Z
# 6        2020-12-17T15:33:15Z                    2020-12-17T15:33:15Z
# 7        2020-12-17T15:33:15Z                    2020-12-17T15:33:15Z
# 8        2020-12-17T15:33:15Z                    2020-12-17T15:33:15Z
# 9        2020-12-17T15:33:15Z                    2020-12-17T15:33:15Z
# 10       2020-12-17T15:33:15Z                    2020-12-17T15:33:15Z
# 11       2020-12-17T15:33:15Z                    2020-12-17T15:33:15Z
# 12       2020-12-17T15:33:15Z                    2020-12-17T15:33:15Z
# 13       2020-12-17T15:33:15Z                    2020-12-17T15:33:15Z
# 14       2020-12-17T15:33:15Z                    2020-12-17T15:33:15Z
# 15       2020-12-17T15:33:15Z                    2020-12-17T15:33:15Z
# 16       2020-12-17T15:33:15Z                    2020-12-17T15:33:15Z
# 17       2020-12-17T15:33:15Z                    2020-12-17T15:33:15Z
# 18       2020-12-17T15:33:15Z                    2020-12-17T15:33:15Z
# 19       2020-12-17T15:33:15Z                    2020-12-17T15:33:15Z
# 20       2020-12-17T15:33:15Z                    2020-12-17T15:33:15Z
# 21       2020-12-17T15:33:15Z                    2020-12-17T15:33:15Z
# 22       2020-12-17T15:33:15Z                    2020-12-17T15:33:15Z
# 23       2020-12-17T15:33:15Z                    2020-12-17T15:33:15Z
# 24       2020-12-17T15:33:15Z                    2020-12-17T15:33:15Z
# 25       2020-12-17T15:33:15Z                    2020-12-17T15:33:15Z
# 26       2020-12-17T15:33:15Z                    2020-12-17T15:33:15Z
# 27       2020-12-17T15:33:15Z                    2020-12-17T15:33:15Z
# 28       2020-12-17T15:33:15Z                    2020-12-17T15:33:15Z
# 29       2020-12-17T15:33:15Z                    2020-12-17T15:33:15Z
# 30       2020-12-17T15:33:15Z                    2020-12-17T15:33:15Z
# 31       2020-12-17T15:33:15Z                    2020-12-17T15:33:15Z
# 32       2020-12-17T15:33:15Z                    2020-12-17T15:33:15Z
# 33       2020-12-17T15:33:15Z                    2020-12-17T15:33:15Z
# 34       2020-12-17T15:33:15Z                    2020-12-17T15:33:15Z
# 35       2020-12-17T15:33:15Z                    2020-12-17T15:33:15Z
# 36       2020-12-17T15:33:15Z                    2020-12-17T15:33:15Z
# 37       2020-12-17T15:33:15Z                    2020-12-17T15:33:15Z
# 38       2020-12-17T15:33:15Z                    2020-12-17T15:33:15Z
# 39       2020-12-17T15:33:15Z                    2020-12-17T15:33:15Z
# 40       2020-12-17T15:33:15Z                    2020-12-17T15:33:15Z
# 41       2020-12-17T15:33:15Z                    2020-12-17T15:33:15Z
# 42       2020-12-17T15:33:15Z                    2020-12-17T15:33:15Z
# 43       2020-12-17T15:33:15Z                    2020-12-17T15:33:15Z
# 44       2020-12-17T15:33:15Z                    2020-12-17T15:33:15Z
# 45       2020-12-17T15:33:15Z                    2020-12-17T15:33:15Z
# 46       2020-12-17T15:33:15Z                    2020-12-17T15:33:15Z
# 47       2020-12-17T15:33:15Z                    2020-12-17T15:33:15Z
#
#    probabilityofoccurrence                   value validitystatus  \
# 0                  certain  VC Noordwest-Nederland         active
# 1                  certain  VC Noordwest-Nederland         active
# 2                  certain  VC Noordwest-Nederland         active
# 3                  certain  VC Noordwest-Nederland         active
# 4                  certain  VC Noordwest-Nederland         active
# 5                  certain  VC Noordwest-Nederland         active
# 6                  certain  VC Noordwest-Nederland         active
# 7                  certain  VC Noordwest-Nederland         active
# 8                  certain  VC Noordwest-Nederland         active
# 9                  certain  VC Noordwest-Nederland         active
# 10                 certain  VC Noordwest-Nederland         active
# 11                 certain  VC Noordwest-Nederland         active
# 12                 certain  VC Noordwest-Nederland         active
# 13                 certain  VC Noordwest-Nederland         active
# 14                 certain  VC Noordwest-Nederland         active
# 15                 certain  VC Noordwest-Nederland         active
# 16                 certain  VC Noordwest-Nederland         active
# 17                 certain  VC Noordwest-Nederland         active
# 18                 certain  VC Noordwest-Nederland         active
# 19                 certain  VC Noordwest-Nederland         active
# 20                 certain  VC Noordwest-Nederland         active
# 21                 certain  VC Noordwest-Nederland         active
# 22                 certain  VC Noordwest-Nederland         active
# 23                 certain  VC Noordwest-Nederland         active
# 24                 certain  VC Noordwest-Nederland         active
# 25                 certain  VC Noordwest-Nederland         active
# 26                 certain  VC Noordwest-Nederland         active
# 27                 certain  VC Noordwest-Nederland         active
# 28                 certain  VC Noordwest-Nederland         active
# 29                 certain  VC Noordwest-Nederland         active
# 30                 certain  VC Noordwest-Nederland         active
# 31                 certain  VC Noordwest-Nederland         active
# 32                 certain  VC Noordwest-Nederland         active
# 33                 certain  VC Noordwest-Nederland         active
# 34                 certain  VC Noordwest-Nederland         active
# 35                 certain  VC Noordwest-Nederland         active
# 36                 certain  VC Noordwest-Nederland         active
# 37                 certain  VC Noordwest-Nederland         active
# 38                 certain  VC Noordwest-Nederland         active
# 39                 certain  VC Noordwest-Nederland         active
# 40                 certain  VC Noordwest-Nederland         active
# 41                 certain  VC Noordwest-Nederland         active
# 42                 certain  VC Noordwest-Nederland         active
# 43                 certain  VC Noordwest-Nederland         active
# 44                 certain  VC Noordwest-Nederland         active
# 45                 certain  VC Noordwest-Nederland         active
# 46                 certain  VC Noordwest-Nederland         active
# 47                 certain  VC Noordwest-Nederland         active
#
#         overallstarttime  latitude longitude alertclocationcountrycode  \
# 0   2020-12-17T15:32:36Z  52.42696  4.682106                         8
# 1   2020-12-17T15:32:36Z  52.42696  4.682106                         8
# 2   2020-12-17T15:32:36Z  52.42696  4.682106                         8
# 3   2020-12-17T15:32:36Z  52.42696  4.682106                         8
# 4   2020-12-17T15:32:36Z  52.42696  4.682106                         8
# 5   2020-12-17T15:32:36Z  52.42696  4.682106                         8
# 6   2020-12-17T15:32:36Z  52.42696  4.682106                         8
# 7   2020-12-17T15:32:36Z  52.42696  4.682106                         8
# 8   2020-12-17T15:32:36Z  52.42696  4.682106                         8
# 9   2020-12-17T15:32:36Z  52.42696  4.682106                         8
# 10  2020-12-17T15:32:36Z  52.42696  4.682106                         8
# 11  2020-12-17T15:32:36Z  52.42696  4.682106                         8
# 12  2020-12-17T15:32:36Z  52.42696  4.682106                         8
# 13  2020-12-17T15:32:36Z  52.42696  4.682106                         8
# 14  2020-12-17T15:32:36Z  52.42696  4.682106                         8
# 15  2020-12-17T15:32:36Z  52.42696  4.682106                         8
# 16  2020-12-17T15:32:36Z  52.42696  4.682106                         8
# 17  2020-12-17T15:32:36Z  52.42696  4.682106                         8
# 18  2020-12-17T15:32:36Z  52.42696  4.682106                         8
# 19  2020-12-17T15:32:36Z  52.42696  4.682106                         8
# 20  2020-12-17T15:32:36Z  52.42696  4.682106                         8
# 21  2020-12-17T15:32:36Z  52.42696  4.682106                         8
# 22  2020-12-17T15:32:36Z  52.42696  4.682106                         8
# 23  2020-12-17T15:32:36Z  52.42696  4.682106                         8
# 24  2020-12-17T15:32:36Z  52.42696  4.682106                         8
# 25  2020-12-17T15:32:36Z  52.42696  4.682106                         8
# 26  2020-12-17T15:32:36Z  52.42696  4.682106                         8
# 27  2020-12-17T15:32:36Z  52.42696  4.682106                         8
# 28  2020-12-17T15:32:36Z  52.42696  4.682106                         8
# 29  2020-12-17T15:32:36Z  52.42696  4.682106                         8
# 30  2020-12-17T15:32:36Z  52.42696  4.682106                         8
# 31  2020-12-17T15:32:36Z  52.42696  4.682106                         8
# 32  2020-12-17T15:32:36Z  52.42696  4.682106                         8
# 33  2020-12-17T15:32:36Z  52.42696  4.682106                         8
# 34  2020-12-17T15:32:36Z  52.42696  4.682106                         8
# 35  2020-12-17T15:32:36Z  52.42696  4.682106                         8
# 36  2020-12-17T15:32:36Z  52.42696  4.682106                         8
# 37  2020-12-17T15:32:36Z  52.42696  4.682106                         8
# 38  2020-12-17T15:32:36Z  52.42696  4.682106                         8
# 39  2020-12-17T15:32:36Z  52.42696  4.682106                         8
# 40  2020-12-17T15:32:36Z  52.42696  4.682106                         8
# 41  2020-12-17T15:32:36Z  52.42696  4.682106                         8
# 42  2020-12-17T15:32:36Z  52.42696  4.682106                         8
# 43  2020-12-17T15:32:36Z  52.42696  4.682106                         8
# 44  2020-12-17T15:32:36Z  52.42696  4.682106                         8
# 45  2020-12-17T15:32:36Z  52.42696  4.682106                         8
# 46  2020-12-17T15:32:36Z  52.42696  4.682106                         8
# 47  2020-12-17T15:32:36Z  52.42696  4.682106                         8
#
#    alertclocationtablenumber alertclocationtableversion alertcdirectioncoded  \
# 0                       5.21                          A             negative
# 1                       5.21                          A             negative
# 2                       5.21                          A             negative
# 3                       5.21                          A             negative
# 4                       5.21                          A             negative
# 5                       5.21                          A             negative
# 6                       5.21                          A             negative
# 7                       5.21                          A             negative
# 8                       5.21                          A             negative
# 9                       5.21                          A             negative
# 10                      5.21                          A             negative
# 11                      5.21                          A             negative
# 12                      5.21                          A             negative
# 13                      5.21                          A             negative
# 14                      5.21                          A             negative
# 15                      5.21                          A             negative
# 16                      5.21                          A             negative
# 17                      5.21                          A             negative
# 18                      5.21                          A             negative
# 19                      5.21                          A             negative
# 20                      5.21                          A             negative
# 21                      5.21                          A             negative
# 22                      5.21                          A             negative
# 23                      5.21                          A             negative
# 24                      5.21                          A             negative
# 25                      5.21                          A             negative
# 26                      5.21                          A             negative
# 27                      5.21                          A             negative
# 28                      5.21                          A             negative
# 29                      5.21                          A             negative
# 30                      5.21                          A             negative
# 31                      5.21                          A             negative
# 32                      5.21                          A             negative
# 33                      5.21                          A             negative
# 34                      5.21                          A             negative
# 35                      5.21                          A             negative
# 36                      5.21                          A             negative
# 37                      5.21                          A             negative
# 38                      5.21                          A             negative
# 39                      5.21                          A             negative
# 40                      5.21                          A             negative
# 41                      5.21                          A             negative
# 42                      5.21                          A             negative
# 43                      5.21                          A             negative
# 44                      5.21                          A             negative
# 45                      5.21                          A             negative
# 46                      5.21                          A             negative
# 47                      5.21                          A             negative
#
#    specificlocation offsetdistance alertcmethod4secondarypointlocation  \
# 0             10589         [1100]                           [[10591]]
# 1             10589         [1100]                           [[10591]]
# 2             10589         [1100]                           [[10591]]
# 3             10589         [1100]                           [[10591]]
# 4             10589         [1100]                           [[10591]]
# 5             10589         [1100]                           [[10591]]
# 6             10589         [1100]                           [[10591]]
# 7             10589         [1100]                           [[10591]]
# 8             10589         [1100]                           [[10591]]
# 9             10589         [1100]                           [[10591]]
# 10            10589         [1100]                           [[10591]]
# 11            10589         [1100]                           [[10591]]
# 12            10589         [1100]                           [[10591]]
# 13            10589         [1100]                           [[10591]]
# 14            10589         [1100]                           [[10591]]
# 15            10589         [1100]                           [[10591]]
# 16            10589         [1100]                           [[10591]]
# 17            10589         [1100]                           [[10591]]
# 18            10589         [1100]                           [[10591]]
# 19            10589         [1100]                           [[10591]]
# 20            10589         [1100]                           [[10591]]
# 21            10589         [1100]                           [[10591]]
# 22            10589         [1100]                           [[10591]]
# 23            10589         [1100]                           [[10591]]
# 24            10589         [1100]                           [[10591]]
# 25            10589         [1100]                           [[10591]]
# 26            10589         [1100]                           [[10591]]
# 27            10589         [1100]                           [[10591]]
# 28            10589         [1100]                           [[10591]]
# 29            10589         [1100]                           [[10591]]
# 30            10589         [1100]                           [[10591]]
# 31            10589         [1100]                           [[10591]]
# 32            10589         [1100]                           [[10591]]
# 33            10589         [1100]                           [[10591]]
# 34            10589         [1100]                           [[10591]]
# 35            10589         [1100]                           [[10591]]
# 36            10589         [1100]                           [[10591]]
# 37            10589         [1100]                           [[10591]]
# 38            10589         [1100]                           [[10591]]
# 39            10589         [1100]                           [[10591]]
# 40            10589         [1100]                           [[10591]]
# 41            10589         [1100]                           [[10591]]
# 42            10589         [1100]                           [[10591]]
# 43            10589         [1100]                           [[10591]]
# 44            10589         [1100]                           [[10591]]
# 45            10589         [1100]                           [[10591]]
# 46            10589         [1100]                           [[10591]]
# 47            10589         [1100]                           [[10591]]
#
#    linearcoordinatesstartpoint pointcoordinates linearcoordinatesendpoint  \
# 0     [[52.42696], [4.682106]]       [52.42696]  [[52.42696], [4.682106]]
# 1     [[52.42696], [4.682106]]       [52.42696]  [[52.42696], [4.682106]]
# 2     [[52.42696], [4.682106]]       [52.42696]  [[52.42696], [4.682106]]
# 3     [[52.42696], [4.682106]]       [52.42696]  [[52.42696], [4.682106]]
# 4     [[52.42696], [4.682106]]       [52.42696]  [[52.42696], [4.682106]]
# 5     [[52.42696], [4.682106]]       [52.42696]  [[52.42696], [4.682106]]
# 6     [[52.42696], [4.682106]]       [52.42696]  [[52.42696], [4.682106]]
# 7     [[52.42696], [4.682106]]       [52.42696]  [[52.42696], [4.682106]]
# 8     [[52.42696], [4.682106]]       [52.42696]  [[52.42696], [4.682106]]
# 9     [[52.42696], [4.682106]]       [52.42696]  [[52.42696], [4.682106]]
# 10    [[52.42696], [4.682106]]       [52.42696]  [[52.42696], [4.682106]]
# 11    [[52.42696], [4.682106]]       [52.42696]  [[52.42696], [4.682106]]
# 12    [[52.42696], [4.682106]]       [52.42696]  [[52.42696], [4.682106]]
# 13    [[52.42696], [4.682106]]       [52.42696]  [[52.42696], [4.682106]]
# 14    [[52.42696], [4.682106]]       [52.42696]  [[52.42696], [4.682106]]
# 15    [[52.42696], [4.682106]]       [52.42696]  [[52.42696], [4.682106]]
# 16    [[52.42696], [4.682106]]       [52.42696]  [[52.42696], [4.682106]]
# 17    [[52.42696], [4.682106]]       [52.42696]  [[52.42696], [4.682106]]
# 18    [[52.42696], [4.682106]]       [52.42696]  [[52.42696], [4.682106]]
# 19    [[52.42696], [4.682106]]       [52.42696]  [[52.42696], [4.682106]]
# 20    [[52.42696], [4.682106]]       [52.42696]  [[52.42696], [4.682106]]
# 21    [[52.42696], [4.682106]]       [52.42696]  [[52.42696], [4.682106]]
# 22    [[52.42696], [4.682106]]       [52.42696]  [[52.42696], [4.682106]]
# 23    [[52.42696], [4.682106]]       [52.42696]  [[52.42696], [4.682106]]
# 24    [[52.42696], [4.682106]]       [52.42696]  [[52.42696], [4.682106]]
# 25    [[52.42696], [4.682106]]       [52.42696]  [[52.42696], [4.682106]]
# 26    [[52.42696], [4.682106]]       [52.42696]  [[52.42696], [4.682106]]
# 27    [[52.42696], [4.682106]]       [52.42696]  [[52.42696], [4.682106]]
# 28    [[52.42696], [4.682106]]       [52.42696]  [[52.42696], [4.682106]]
# 29    [[52.42696], [4.682106]]       [52.42696]  [[52.42696], [4.682106]]
# 30    [[52.42696], [4.682106]]       [52.42696]  [[52.42696], [4.682106]]
# 31    [[52.42696], [4.682106]]       [52.42696]  [[52.42696], [4.682106]]
# 32    [[52.42696], [4.682106]]       [52.42696]  [[52.42696], [4.682106]]
# 33    [[52.42696], [4.682106]]       [52.42696]  [[52.42696], [4.682106]]
# 34    [[52.42696], [4.682106]]       [52.42696]  [[52.42696], [4.682106]]
# 35    [[52.42696], [4.682106]]       [52.42696]  [[52.42696], [4.682106]]
# 36    [[52.42696], [4.682106]]       [52.42696]  [[52.42696], [4.682106]]
# 37    [[52.42696], [4.682106]]       [52.42696]  [[52.42696], [4.682106]]
# 38    [[52.42696], [4.682106]]       [52.42696]  [[52.42696], [4.682106]]
# 39    [[52.42696], [4.682106]]       [52.42696]  [[52.42696], [4.682106]]
# 40    [[52.42696], [4.682106]]       [52.42696]  [[52.42696], [4.682106]]
# 41    [[52.42696], [4.682106]]       [52.42696]  [[52.42696], [4.682106]]
# 42    [[52.42696], [4.682106]]       [52.42696]  [[52.42696], [4.682106]]
# 43    [[52.42696], [4.682106]]       [52.42696]  [[52.42696], [4.682106]]
# 44    [[52.42696], [4.682106]]       [52.42696]  [[52.42696], [4.682106]]
# 45    [[52.42696], [4.682106]]       [52.42696]  [[52.42696], [4.682106]]
# 46    [[52.42696], [4.682106]]       [52.42696]  [[52.42696], [4.682106]]
# 47    [[52.42696], [4.682106]]       [52.42696]  [[52.42696], [4.682106]]
#
#    safetyrelatedmessage mobilitytype vehicleobstructiontype
# 0                  true   stationary      brokenDownVehicle
# 1                  true   stationary      brokenDownVehicle
# 2                  true   stationary      brokenDownVehicle
# 3                  true   stationary      brokenDownVehicle
# 4                  true   stationary      brokenDownVehicle
# 5                  true   stationary      brokenDownVehicle
# 6                  true   stationary      brokenDownVehicle
# 7                  true   stationary      brokenDownVehicle
# 8                  true   stationary      brokenDownVehicle
# 9                  true   stationary      brokenDownVehicle
# 10                 true   stationary      brokenDownVehicle
# 11                 true   stationary      brokenDownVehicle
# 12                 true   stationary      brokenDownVehicle
# 13                 true   stationary      brokenDownVehicle
# 14                 true   stationary      brokenDownVehicle
# 15                 true   stationary      brokenDownVehicle
# 16                 true   stationary      brokenDownVehicle
# 17                 true   stationary      brokenDownVehicle
# 18                 true   stationary      brokenDownVehicle
# 19                 true   stationary      brokenDownVehicle
# 20                 true   stationary      brokenDownVehicle
# 21                 true   stationary      brokenDownVehicle
# 22                 true   stationary      brokenDownVehicle
# 23                 true   stationary      brokenDownVehicle
# 24                 true   stationary      brokenDownVehicle
# 25                 true   stationary      brokenDownVehicle
# 26                 true   stationary      brokenDownVehicle
# 27                 true   stationary      brokenDownVehicle
# 28                 true   stationary      brokenDownVehicle
# 29                 true   stationary      brokenDownVehicle
# 30                 true   stationary      brokenDownVehicle
# 31                 true   stationary      brokenDownVehicle
# 32                 true   stationary      brokenDownVehicle
# 33                 true   stationary      brokenDownVehicle
# 34                 true   stationary      brokenDownVehicle
# 35                 true   stationary      brokenDownVehicle
# 36                 true   stationary      brokenDownVehicle
# 37                 true   stationary      brokenDownVehicle
# 38                 true   stationary      brokenDownVehicle
# 39                 true   stationary      brokenDownVehicle
# 40                 true   stationary      brokenDownVehicle
# 41                 true   stationary      brokenDownVehicle
# 42                 true   stationary      brokenDownVehicle
# 43                 true   stationary      brokenDownVehicle
# 44                 true   stationary      brokenDownVehicle
# 45                 true   stationary      brokenDownVehicle
# 46                 true   stationary      brokenDownVehicle
# 47                 true   stationary      brokenDownVehicle

# %%
soup.find_all('publicationtime')[0].contents
# Out:
# ['2020-12-17T16:44:50.449Z']

# %%
soup.find('situation').findChildren()
# Out:
# [<overallseverity>unknown</overallseverity>,
#  <situationversiontime>2020-12-17T15:33:15Z</situationversiontime>,
#  <headerinformation><confidentiality>noRestriction</confidentiality><informationstatus>real</informationstatus></headerinformation>,
#  <confidentiality>noRestriction</confidentiality>,
#  <informationstatus>real</informationstatus>,
#  <situationrecord id="RWS03_956972_1" version="2" xsi:type="VehicleObstruction"><situationrecordcreationreference>LCM-LCM20168480_IM_1</situationrecordcreationreference><situationrecordcreationtime>2020-12-17T15:33:15Z</situationrecordcreationtime><situationrecordobservationtime>2020-12-17T15:33:15Z</situationrecordobservationtime><situationrecordversiontime>2020-12-17T15:33:15Z</situationrecordversiontime><situationrecordfirstsupplierversiontime>2020-12-17T15:33:15Z</situationrecordfirstsupplierversiontime><probabilityofoccurrence>certain</probabilityofoccurrence><source><sourcename><values><value lang="nl">VC Noordwest-Nederland</value></values></sourcename></source><validity><validitystatus>active</validitystatus><validitytimespecification><overallstarttime>2020-12-17T15:32:36Z</overallstarttime></validitytimespecification></validity><groupoflocations xsi:type="Linear"><locationfordisplay><latitude>52.42696</latitude><longitude>4.682106</longitude></locationfordisplay><alertclinear xsi:type="AlertCMethod4Linear"><alertclocationcountrycode>8</alertclocationcountrycode><alertclocationtablenumber>5.21</alertclocationtablenumber><alertclocationtableversion>A</alertclocationtableversion><alertcdirection><alertcdirectioncoded>negative</alertcdirectioncoded></alertcdirection><alertcmethod4primarypointlocation><alertclocation><specificlocation>10589</specificlocation></alertclocation><offsetdistance><offsetdistance>1100</offsetdistance></offsetdistance></alertcmethod4primarypointlocation><alertcmethod4secondarypointlocation><alertclocation><specificlocation>10591</specificlocation></alertclocation><offsetdistance><offsetdistance>2400</offsetdistance></offsetdistance></alertcmethod4secondarypointlocation></alertclinear><linearextension><linearbycoordinatesextension><linearcoordinatesstartpoint><pointcoordinates><latitude>52.42696</latitude><longitude>4.682106</longitude></pointcoordinates></linearcoordinatesstartpoint><linearcoordinatesendpoint><pointcoordinates><latitude>52.42696</latitude><longitude>4.682106</longitude></pointcoordinates></linearcoordinatesendpoint></linearbycoordinatesextension></linearextension></groupoflocations><situationrecordextension><situationrecordextendedapproved><safetyrelatedmessage>true</safetyrelatedmessage></situationrecordextendedapproved></situationrecordextension><mobilityofobstruction><mobilitytype>stationary</mobilitytype></mobilityofobstruction><vehicleobstructiontype>brokenDownVehicle</vehicleobstructiontype></situationrecord>,
#  <situationrecordcreationreference>LCM-LCM20168480_IM_1</situationrecordcreationreference>,
#  <situationrecordcreationtime>2020-12-17T15:33:15Z</situationrecordcreationtime>,
#  <situationrecordobservationtime>2020-12-17T15:33:15Z</situationrecordobservationtime>,
#  <situationrecordversiontime>2020-12-17T15:33:15Z</situationrecordversiontime>,
#  <situationrecordfirstsupplierversiontime>2020-12-17T15:33:15Z</situationrecordfirstsupplierversiontime>,
#  <probabilityofoccurrence>certain</probabilityofoccurrence>,
#  <source><sourcename><values><value lang="nl">VC Noordwest-Nederland</value></values></sourcename></source>,
#  <sourcename><values><value lang="nl">VC Noordwest-Nederland</value></values></sourcename>,
#  <values><value lang="nl">VC Noordwest-Nederland</value></values>,
#  <value lang="nl">VC Noordwest-Nederland</value>,
#  <validity><validitystatus>active</validitystatus><validitytimespecification><overallstarttime>2020-12-17T15:32:36Z</overallstarttime></validitytimespecification></validity>,
#  <validitystatus>active</validitystatus>,
#  <validitytimespecification><overallstarttime>2020-12-17T15:32:36Z</overallstarttime></validitytimespecification>,
#  <overallstarttime>2020-12-17T15:32:36Z</overallstarttime>,
#  <groupoflocations xsi:type="Linear"><locationfordisplay><latitude>52.42696</latitude><longitude>4.682106</longitude></locationfordisplay><alertclinear xsi:type="AlertCMethod4Linear"><alertclocationcountrycode>8</alertclocationcountrycode><alertclocationtablenumber>5.21</alertclocationtablenumber><alertclocationtableversion>A</alertclocationtableversion><alertcdirection><alertcdirectioncoded>negative</alertcdirectioncoded></alertcdirection><alertcmethod4primarypointlocation><alertclocation><specificlocation>10589</specificlocation></alertclocation><offsetdistance><offsetdistance>1100</offsetdistance></offsetdistance></alertcmethod4primarypointlocation><alertcmethod4secondarypointlocation><alertclocation><specificlocation>10591</specificlocation></alertclocation><offsetdistance><offsetdistance>2400</offsetdistance></offsetdistance></alertcmethod4secondarypointlocation></alertclinear><linearextension><linearbycoordinatesextension><linearcoordinatesstartpoint><pointcoordinates><latitude>52.42696</latitude><longitude>4.682106</longitude></pointcoordinates></linearcoordinatesstartpoint><linearcoordinatesendpoint><pointcoordinates><latitude>52.42696</latitude><longitude>4.682106</longitude></pointcoordinates></linearcoordinatesendpoint></linearbycoordinatesextension></linearextension></groupoflocations>,
#  <locationfordisplay><latitude>52.42696</latitude><longitude>4.682106</longitude></locationfordisplay>,
#  <latitude>52.42696</latitude>,
#  <longitude>4.682106</longitude>,
#  <alertclinear xsi:type="AlertCMethod4Linear"><alertclocationcountrycode>8</alertclocationcountrycode><alertclocationtablenumber>5.21</alertclocationtablenumber><alertclocationtableversion>A</alertclocationtableversion><alertcdirection><alertcdirectioncoded>negative</alertcdirectioncoded></alertcdirection><alertcmethod4primarypointlocation><alertclocation><specificlocation>10589</specificlocation></alertclocation><offsetdistance><offsetdistance>1100</offsetdistance></offsetdistance></alertcmethod4primarypointlocation><alertcmethod4secondarypointlocation><alertclocation><specificlocation>10591</specificlocation></alertclocation><offsetdistance><offsetdistance>2400</offsetdistance></offsetdistance></alertcmethod4secondarypointlocation></alertclinear>,
#  <alertclocationcountrycode>8</alertclocationcountrycode>,
#  <alertclocationtablenumber>5.21</alertclocationtablenumber>,
#  <alertclocationtableversion>A</alertclocationtableversion>,
#  <alertcdirection><alertcdirectioncoded>negative</alertcdirectioncoded></alertcdirection>,
#  <alertcdirectioncoded>negative</alertcdirectioncoded>,
#  <alertcmethod4primarypointlocation><alertclocation><specificlocation>10589</specificlocation></alertclocation><offsetdistance><offsetdistance>1100</offsetdistance></offsetdistance></alertcmethod4primarypointlocation>,
#  <alertclocation><specificlocation>10589</specificlocation></alertclocation>,
#  <specificlocation>10589</specificlocation>,
#  <offsetdistance><offsetdistance>1100</offsetdistance></offsetdistance>,
#  <offsetdistance>1100</offsetdistance>,
#  <alertcmethod4secondarypointlocation><alertclocation><specificlocation>10591</specificlocation></alertclocation><offsetdistance><offsetdistance>2400</offsetdistance></offsetdistance></alertcmethod4secondarypointlocation>,
#  <alertclocation><specificlocation>10591</specificlocation></alertclocation>,
#  <specificlocation>10591</specificlocation>,
#  <offsetdistance><offsetdistance>2400</offsetdistance></offsetdistance>,
#  <offsetdistance>2400</offsetdistance>,
#  <linearextension><linearbycoordinatesextension><linearcoordinatesstartpoint><pointcoordinates><latitude>52.42696</latitude><longitude>4.682106</longitude></pointcoordinates></linearcoordinatesstartpoint><linearcoordinatesendpoint><pointcoordinates><latitude>52.42696</latitude><longitude>4.682106</longitude></pointcoordinates></linearcoordinatesendpoint></linearbycoordinatesextension></linearextension>,
#  <linearbycoordinatesextension><linearcoordinatesstartpoint><pointcoordinates><latitude>52.42696</latitude><longitude>4.682106</longitude></pointcoordinates></linearcoordinatesstartpoint><linearcoordinatesendpoint><pointcoordinates><latitude>52.42696</latitude><longitude>4.682106</longitude></pointcoordinates></linearcoordinatesendpoint></linearbycoordinatesextension>,
#  <linearcoordinatesstartpoint><pointcoordinates><latitude>52.42696</latitude><longitude>4.682106</longitude></pointcoordinates></linearcoordinatesstartpoint>,
#  <pointcoordinates><latitude>52.42696</latitude><longitude>4.682106</longitude></pointcoordinates>,
#  <latitude>52.42696</latitude>,
#  <longitude>4.682106</longitude>,
#  <linearcoordinatesendpoint><pointcoordinates><latitude>52.42696</latitude><longitude>4.682106</longitude></pointcoordinates></linearcoordinatesendpoint>,
#  <pointcoordinates><latitude>52.42696</latitude><longitude>4.682106</longitude></pointcoordinates>,
#  <latitude>52.42696</latitude>,
#  <longitude>4.682106</longitude>,
#  <situationrecordextension><situationrecordextendedapproved><safetyrelatedmessage>true</safetyrelatedmessage></situationrecordextendedapproved></situationrecordextension>,
#  <situationrecordextendedapproved><safetyrelatedmessage>true</safetyrelatedmessage></situationrecordextendedapproved>,
#  <safetyrelatedmessage>true</safetyrelatedmessage>,
#  <mobilityofobstruction><mobilitytype>stationary</mobilitytype></mobilityofobstruction>,
#  <mobilitytype>stationary</mobilitytype>,
#  <vehicleobstructiontype>brokenDownVehicle</vehicleobstructiontype>]

# %% [markdown]
# 1. Transform xml file into dataframe
# 2. Compare files from different dates - what is the update process?
# 3. Find meaningful connections with other data
# 4. Set up pipeline
